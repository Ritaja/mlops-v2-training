# %% [markdown]
# # Feathr Feature Store on Azure Demo Notebook
#
# This notebook illustrates the use of Feature Store to create a model that predicts NYC Taxi fares. It includes these steps:
#
#
# This tutorial demonstrates the basic usage of Feathr Feature Store on Azure. It includes these steps:
#
# 1. Setup Feathr Environment
# 2. Initialize Feathr Client
# 3. Defining Features with Feathr
# 4. Registering Features to the Feathr feature registry
# 5. Creating training data point-in-time correct features joins
# 6. Materializing features to an offline/online store
#
# In this tutorial, we use Feathr Feature Store to create a model that predicts NYC Taxi fares. The dataset comes from [here](https://www1.nyc.gov/site/tlc/about/tlc-trip-record-data.page). The feature flow is as below:
#
# ![Feature Flow](https://github.com/linkedin/feathr/blob/main/docs/images/feature_flow.png?raw=true)

# %% [markdown]
# # Setup Feathr Environment

# %% [markdown]
# **REQUIRED STEP: Fill in the resource prefix when provisioning the resources**
#
# ***Prior to running the notebook, make sure you have deployed all required resources in your Azure subscription.***

# %%
# replace with your prefix
resource_prefix = "rifeathr"
storage_accountname = "rifeathrdls"
storage_containername = "nyctaxi"

# %%
import glob
import os
import tempfile
from datetime import datetime, timedelta
from math import sqrt

import pandas as pd
import pandavro as pdx
from feathr import FeathrClient
from feathr import BOOLEAN, FLOAT, INT32, ValueType
from feathr import Feature, DerivedFeature, FeatureAnchor
from feathr import BackfillTime, MaterializationSettings
from feathr import FeatureQuery, ObservationSettings
from feathr import RedisSink, HdfsSink, JdbcSink
from feathr import INPUT_CONTEXT, HdfsSource
from feathr import WindowAggTransformation
from feathr import TypedKey
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
from azure.identity import DefaultAzureCredential
from azure.keyvault.secrets import SecretClient

# %%
# Get all the required credentials from Azure Key Vault
key_vault_name=resource_prefix+"kv"
synapse_workspace_url=resource_prefix+"syws"
adls_account=resource_prefix+"dls"
adls_fs_name=resource_prefix+"fs"
purview_name=resource_prefix+"purview"
key_vault_uri = f"https://{key_vault_name}.vault.azure.net"
credential = DefaultAzureCredential(exclude_interactive_browser_credential=False)
client = SecretClient(vault_url=key_vault_uri, credential=credential)
secretName = "FEATHR-ONLINE-STORE-CONN"
retrieved_secret = client.get_secret(secretName).value

# Set the resource link
os.environ['spark_config__azure_synapse__dev_url'] = f'https://{synapse_workspace_url}.dev.azuresynapse.net'
os.environ['spark_config__azure_synapse__pool_name'] = 'spark31'
os.environ['spark_config__azure_synapse__workspace_dir'] = f'abfss://{adls_fs_name}@{adls_account}.dfs.core.windows.net/feathr_project'
# os.environ['feature_registry__purview__purview_name'] = f'{purview_name}'
os.environ['FEATURE_REGISTRY__API_ENDPOINT']= f'https://{resource_prefix}webapp.azurewebsites.net/api/v1'
os.environ['online_store__SQL_RIFEATHRDB__USER'] = "sqladmin"
os.environ['online_store__SQL_RIFEATHRDB__PASSWORD'] = "ThisIsNotVerySecure!"
feathr_output_path = f'abfss://{adls_fs_name}@{adls_account}.dfs.core.windows.net/feathr_output'

# %% [markdown]
# # Initialize Feathr Client

# %%
config_file_name = "feathr_config.yaml" 
feathr_client = FeathrClient(config_path=config_file_name, credential=credential)
# Out:
# 2022-12-03 07:21:30.345 | INFO     | feathr.utils._envvariableutil:get_environment_variable_with_default:51 - secrets__azure_key_vault__name not found in the config file.
# 2022-12-03 07:21:30.403 | INFO     | feathr.utils._envvariableutil:get_environment_variable_with_default:51 - online_store__redis__host not found in the config file.
# 2022-12-03 07:21:30.440 | INFO     | feathr.utils._envvariableutil:get_environment_variable_with_default:51 - online_store__redis__port not found in the config file.
# 2022-12-03 07:21:30.467 | INFO     | feathr.utils._envvariableutil:get_environment_variable_with_default:51 - online_store__redis__ssl_enabled not found in the config file.
# 2022-12-03 07:21:30.675 | INFO     | feathr.utils._envvariableutil:get_environment_variable_with_default:51 - spark_config__azure_synapse__feathr_runtime_location not found in the config file.
# 2022-12-03 07:21:34.641 | INFO     | feathr.utils._envvariableutil:get_environment_variable:82 - REDIS_PASSWORD is not set in the environment variables.
# 2022-12-03 07:21:34.762 | INFO     | feathr.utils._envvariableutil:get_environment_variable_with_default:51 - secrets__azure_key_vault__name not found in the config file.
# 2022-12-03 07:21:34.766 | INFO     | feathr.client:__init__:176 - Feathr Client 0.9.0 initialized successfully

# %% [markdown]
# # Defining Features with Feathr
#
# In Feathr, a feature is viewed as a function, mapping from entity id or key, and timestamp to a feature value. For more details on feature definition, please refer to the [Feathr Feature Definition Guide](https://github.com/linkedin/feathr/blob/main/docs/concepts/feature-definition.md)
#
#
# 1. The typed key (a.k.a. entity id) identifies the subject of feature, e.g. a user id, 123.
# 2. The feature name is the aspect of the entity that the feature is indicating, e.g. the age of the user.
# 3. The feature value is the actual value of that aspect at a particular time, e.g. the value is 30 at year 2022.

# %% [markdown]
# Note that, in some cases, such as features defined on top of request data, may have no entity key or timestamp.
# It is merely a function/transformation executing against request data at runtime.
# For example, the day of week of the request, which is calculated by converting the request UNIX timestamp.

# %% [markdown]
# ## Define Sources Section with UDFs
# A feature source is needed for anchored features that describes the raw data in which the feature values are computed from. See the python documentation to get the details on each input column.

# %%
# define a pre-processing function/UDF to be used on spark 
from pyspark.sql import SparkSession, DataFrame
def feathr_udf_day_calc(df: DataFrame) -> DataFrame:
    from pyspark.sql.functions import dayofweek, dayofyear, col
    df = df.withColumn("fare_amount_cents", col("fare_amount")*100)
    return df

# define the data source
batch_source = HdfsSource(name="nycTaxiBatchSource",
                          path="abfss://{container_name}@{storage_account}.dfs.core.windows.net/nyc_taxi.parquet".format(storage_account=storage_accountname, container_name=storage_containername),
                          event_timestamp_column="lpep_dropoff_datetime",
                          preprocessing=feathr_udf_day_calc,
                          timestamp_format="yyyy-MM-dd HH:mm:ss")

# %% [markdown]
# ### Define Anchors and Features
# A feature is called an anchored feature when the feature is directly extracted from the source data, rather than computed on top of other features. The latter case is called derived feature.

# %%
# define anchor features
f_trip_distance = Feature(name="f_trip_distance",
                          feature_type=FLOAT, transform="trip_distance")
f_trip_time_duration = Feature(name="f_trip_time_duration",
                               feature_type=INT32,
                               transform="(to_unix_timestamp(lpep_dropoff_datetime) - to_unix_timestamp(lpep_pickup_datetime))/60")

features = [
    f_trip_distance,
    f_trip_time_duration,
    Feature(name="f_is_long_trip_distance",
            feature_type=BOOLEAN,
            transform="cast_float(trip_distance)>30"),
    Feature(name="f_day_of_week",
            feature_type=INT32,
            transform="dayofweek(lpep_dropoff_datetime)"),
]

request_anchor = FeatureAnchor(name="request_features",
                               source=INPUT_CONTEXT,
                               features=features)

# %% [markdown]
# ### Window aggregation features
#
# For window aggregation features, see the supported fields below:
#
# Note that the `agg_func` should be any of these:
#
# | Aggregation Type | Input Type | Description |
# | --- | --- | --- |
# |SUM, COUNT, MAX, MIN, AVG	|Numeric|Applies the the numerical operation on the numeric inputs. |
# |MAX_POOLING, MIN_POOLING, AVG_POOLING	| Numeric Vector | Applies the max/min/avg operation on a per entry bassis for a given a collection of numbers.|
# |LATEST| Any |Returns the latest not-null values from within the defined time window |
#
#
# After you have defined features and sources, bring them together to build an anchor:
#
#
# Note that if the data source is from the observation data, the `source` section should be `INPUT_CONTEXT` to indicate the source of those defined anchors.

# %%
location_id = TypedKey(key_column="DOLocationID",
                       key_column_type=ValueType.INT32,
                       description="location id in NYC",
                       full_name="nyc_taxi.location_id")

# calculate the average trip fare, maximum fare and total fare per location for 90 days
agg_features = [Feature(name="f_location_avg_fare",
                        key=location_id,
                        feature_type=FLOAT,
                        transform=WindowAggTransformation(agg_expr="cast_float(fare_amount)",
                                                          agg_func="AVG",
                                                          window="90d")),
                Feature(name="f_location_max_fare",
                        key=location_id,
                        feature_type=FLOAT,
                        transform=WindowAggTransformation(agg_expr="cast_float(fare_amount)",
                                                          agg_func="MAX",
                                                          window="90d")),
                Feature(name="f_location_total_fare_cents",
                        key=location_id,
                        feature_type=FLOAT,
                        transform=WindowAggTransformation(agg_expr="fare_amount_cents",
                                                          agg_func="SUM",
                                                          window="90d")),
                ]

agg_anchor = FeatureAnchor(name="aggregationFeatures",
                           source=batch_source,
                           features=agg_features)

# %% [markdown]
# ### Derived Features
# Derived features are the features that are computed from other features. They could be computed from anchored features, or other derived features.

# %%
f_trip_time_distance = DerivedFeature(name="f_trip_time_distance",
                                      feature_type=FLOAT,
                                      input_features=[
                                          f_trip_distance, f_trip_time_duration],
                                      transform="f_trip_distance * f_trip_time_duration")

f_trip_time_rounded = DerivedFeature(name="f_trip_time_rounded",
                                     feature_type=INT32,
                                     input_features=[f_trip_time_duration],
                                     transform="f_trip_time_duration % 10")

# %% [markdown]
# And then we need to build those features so that it can be consumed later. Note that we have to build both the "anchor" and the "derived" features (which is not anchored to a source).

# %%
feathr_client.build_features(anchor_list=[agg_anchor, request_anchor], derived_feature_list=[
                      f_trip_time_distance, f_trip_time_rounded])

# %% [markdown]
# ### Registering features
#
# We can also register the features with an Apache Atlas compatible service, such as Azure Purview, and share the registered features across teams:

# %%
credential = DefaultAzureCredential(exclude_interactive_browser_credential=False)

# %%
feathr_client.register_features()
# feathr_client._create_project()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In [13], line 1
# ----> 1 feathr_client.register_features()
#       2 # feathr_client._create_project()
#
# File c:\Users\risengupta\Miniconda3\envs\datascience-env\lib\site-packages\feathr\client.py:201, in FeathrClient.register_features(self, from_context)
#     199 if 'anchor_list' in dir(self) and 'derived_feature_list' in dir(self):
#     200     self.registry.save_to_feature_config_from_context(self.anchor_list, self.derived_feature_list, self.local_workspace_dir)
# --> 201     self.registry.register_features(self.local_workspace_dir, from_context=from_context, anchor_list=self.anchor_list, derived_feature_list=self.derived_feature_list)
#     202 else:
#     203     raise RuntimeError("Please call FeathrClient.build_features() first in order to register features")
#
# File c:\Users\risengupta\Miniconda3\envs\datascience-env\lib\site-packages\feathr\registry\_feathr_registry_client.py:105, in _FeatureRegistry.register_features(self, workspace_path, from_context, anchor_list, derived_feature_list)
#     101     raise RuntimeError(
#     102         "Currently Feathr only supports registering features from context (i.e. you must call FeathrClient.build_features() before calling this function).")
#     104 # Before starting, create the project
# --> 105 self.project_id = self._create_project()
#     107 for anchor in anchor_list:
#     108     source = anchor.source
#
# File c:\Users\risengupta\Miniconda3\envs\datascience-env\lib\site-packages\feathr\registry\_feathr_registry_client.py:151, in _FeatureRegistry._create_project(self)
#     150 def _create_project(self) -> UUID:
# --> 151     r = self._post(f"/projects", {"name": self.project_name})
#     152     self.project_id = UUID(r["guid"])
#     153     return self.project_id
#
# File c:\Users\risengupta\Miniconda3\envs\datascience-env\lib\site-packages\feathr\registry\_feathr_registry_client.py:194, in _FeatureRegistry._post(self, path, body)
#     192 logging.debug("PATH: ", path)
#     193 logging.debug("BODY: ", json.dumps(body, indent=2))
# --> 194 return check(requests.post(f"{self.endpoint}{path}", headers=self._get_auth_header(), json=body)).json()
#
# File c:\Users\risengupta\Miniconda3\envs\datascience-env\lib\site-packages\feathr\registry\_feathr_registry_client.py:381, in check(r)
#     379 def check(r):
#     380     if not r.ok:
# --> 381         raise RuntimeError(
#     382             f"Failed to call registry API, status is {r.status_code}, error is {r.text}")
#     383     return r
#
# RuntimeError: Failed to call registry API, status is 400, error is <html>
# <head><title>400 Request Header Or Cookie Too Large</title></head>
# <body>
# <center><h1>400 Bad Request</h1></center>
# <center>Request Header Or Cookie Too Large</center>
# <hr><center>nginx/1.18.0</center>
# </body>
# </html>

# %% [markdown]
# We can now list the registered features:

# %%
feathr_client.list_registered_features(project_name="nyctaxifs")
# Out:
# [{'name': 'f_trip_time_rounded',
#   'id': '544cdf6d-aaf4-4fe6-b013-f8939c0c73a5',
#   'qualifiedName': 'nyctaxifs__f_trip_time_rounded'},
#  {'name': 'f_trip_time_distance',
#   'id': '298da136-0db4-49d8-8807-689b4b1076d9',
#   'qualifiedName': 'nyctaxifs__f_trip_time_distance'},
#  {'name': 'f_trip_time_duration',
#   'id': '81864281-ee90-4361-b618-f66bd5d4d32b',
#   'qualifiedName': 'nyctaxifs__request_features__f_trip_time_duration'},
#  {'name': 'f_is_long_trip_distance',
#   'id': '4e69f9fc-bb6b-4c0f-8499-212b226e7062',
#   'qualifiedName': 'nyctaxifs__request_features__f_is_long_trip_distance'},
#  {'name': 'f_day_of_week',
#   'id': '7658ed88-491b-4670-b8a2-3e608d0c4652',
#   'qualifiedName': 'nyctaxifs__request_features__f_day_of_week'},
#  {'name': 'f_trip_distance',
#   'id': '6da0dca1-30de-4523-8c7e-a862df4120c8',
#   'qualifiedName': 'nyctaxifs__request_features__f_trip_distance'},
#  {'name': 'f_location_max_fare',
#   'id': '54eb9548-0a89-4297-b75c-f64f161ecae0',
#   'qualifiedName': 'nyctaxifs__aggregationFeatures__f_location_max_fare'},
#  {'name': 'f_location_total_fare_cents',
#   'id': '7e431e7f-47e5-46d2-bc88-39e7caeb8bcf',
#   'qualifiedName': 'nyctaxifs__aggregationFeatures__f_location_total_fare_cents'},
#  {'name': 'f_location_avg_fare',
#   'id': '604aa105-1cd4-4285-b656-8b2e16e26740',
#   'qualifiedName': 'nyctaxifs__aggregationFeatures__f_location_avg_fare'}]

# %% [markdown]
# ## Create training data using point-in-time correct feature join (e.g usage path: ML model training and scoring)
#
# A training dataset usually contains entity id columns, multiple feature columns, event timestamp column and label/target column.
#
# To create a training dataset using Feathr, one needs to provide a feature join configuration file to specify
# what features and how these features should be joined to the observation data.
#
# To learn more on this topic, please refer to [Point-in-time Correctness](https://github.com/linkedin/feathr/blob/main/docs/concepts/point-in-time-join.md)

# %%
output_path = feathr_output_path

# retrieve a list of features with help of the common key
feature_query = FeatureQuery(
    feature_list=["f_location_avg_fare", "f_trip_time_rounded", "f_is_long_trip_distance", "f_location_total_fare_cents"], key=location_id)

# Time settings of the observation data. Used in feature join (so the data useed for join is this data in observeration path combined with feature list described above)
settings = ObservationSettings(
    observation_path="abfss://{container_name}@{storage_account}.dfs.core.windows.net/nyc_taxi.parquet".format(storage_account=storage_accountname, container_name=storage_containername),
    event_timestamp_column="lpep_dropoff_datetime",
    timestamp_format="yyyy-MM-dd HH:mm:ss")
feathr_client.get_offline_features(observation_settings=settings,
                            feature_query=feature_query,
                            output_path=output_path)
feathr_client.wait_job_to_finish(timeout_sec=500)
# Out:
# 2022-12-01 17:13:15.373 | INFO     | feathr.spark_provider._synapse_submission:upload_or_get_cloud_path:67 - Uploading C:\Users\RISENG~1\AppData\Local\Temp\tmpq8_162q6\feathr_pyspark_driver.py to cloud..
# 2022-12-01 17:13:15.373 | INFO     | feathr.spark_provider._synapse_submission:upload_file:412 - Uploading file feathr_pyspark_driver.py
# 2022-12-01 17:13:52.704 | INFO     | feathr.spark_provider._synapse_submission:upload_file:418 - C:\Users\RISENG~1\AppData\Local\Temp\tmpq8_162q6\feathr_pyspark_driver.py is uploaded to location: abfss://rifeathrfs@rifeathrdls.dfs.core.windows.net/feathr_project/feathr_pyspark_driver.py
# 2022-12-01 17:13:52.704 | INFO     | feathr.spark_provider._synapse_submission:upload_or_get_cloud_path:71 - C:\Users\RISENG~1\AppData\Local\Temp\tmpq8_162q6\feathr_pyspark_driver.py is uploaded to location: abfss://rifeathrfs@rifeathrdls.dfs.core.windows.net/feathr_project/feathr_pyspark_driver.py
# 2022-12-01 17:13:52.736 | INFO     | feathr.spark_provider._synapse_submission:upload_or_get_cloud_path:67 - Uploading C:\Users\RISENG~1\AppData\Local\Temp\tmpq8_162q6\feature_join_conf\feature_join.conf to cloud..
# 2022-12-01 17:13:52.736 | INFO     | feathr.spark_provider._synapse_submission:upload_file:412 - Uploading file feature_join.conf
# 2022-12-01 17:13:53.802 | INFO     | feathr.spark_provider._synapse_submission:upload_file:418 - C:\Users\RISENG~1\AppData\Local\Temp\tmpq8_162q6\feature_join_conf\feature_join.conf is uploaded to location: abfss://rifeathrfs@rifeathrdls.dfs.core.windows.net/feathr_project/feature_join.conf
# 2022-12-01 17:13:53.802 | INFO     | feathr.spark_provider._synapse_submission:upload_or_get_cloud_path:71 - C:\Users\RISENG~1\AppData\Local\Temp\tmpq8_162q6\feature_join_conf\feature_join.conf is uploaded to location: abfss://rifeathrfs@rifeathrdls.dfs.core.windows.net/feathr_project/feature_join.conf
# 2022-12-01 17:13:53.802 | INFO     | feathr.spark_provider._synapse_submission:upload_or_get_cloud_path:67 - Uploading C:\Users\RISENG~1\AppData\Local\Temp\tmpq8_162q6\feature_conf/ to cloud..
# 2022-12-01 17:13:53.814 | INFO     | feathr.spark_provider._synapse_submission:upload_file_to_workdir:400 - Uploading folder C:\Users\RISENG~1\AppData\Local\Temp\tmpq8_162q6\feature_conf/
# 2022-12-01 17:13:53.818 | INFO     | feathr.spark_provider._synapse_submission:upload_file:412 - Uploading file auto_generated_anchored_features.conf
# 2022-12-01 17:13:54.173 | INFO     | feathr.spark_provider._synapse_submission:upload_file:418 - C:\Users\risengupta\AppData\Local\Temp\tmpq8_162q6\feature_conf\auto_generated_anchored_features.conf is uploaded to location: abfss://rifeathrfs@rifeathrdls.dfs.core.windows.net/feathr_project/auto_generated_anchored_features.conf
# 2022-12-01 17:13:54.189 | INFO     | feathr.spark_provider._synapse_submission:upload_file:412 - Uploading file auto_generated_derived_features.conf
# 2022-12-01 17:13:54.526 | INFO     | feathr.spark_provider._synapse_submission:upload_file:418 - C:\Users\risengupta\AppData\Local\Temp\tmpq8_162q6\feature_conf\auto_generated_derived_features.conf is uploaded to location: abfss://rifeathrfs@rifeathrdls.dfs.core.windows.net/feathr_project/auto_generated_derived_features.conf
# 2022-12-01 17:13:54.530 | INFO     | feathr.spark_provider._synapse_submission:upload_file:412 - Uploading file auto_generated_request_features.conf
# 2022-12-01 17:13:54.868 | INFO     | feathr.spark_provider._synapse_submission:upload_file:418 - C:\Users\risengupta\AppData\Local\Temp\tmpq8_162q6\feature_conf\auto_generated_request_features.conf is uploaded to location: abfss://rifeathrfs@rifeathrdls.dfs.core.windows.net/feathr_project/auto_generated_request_features.conf
# 2022-12-01 17:13:54.877 | INFO     | feathr.spark_provider._synapse_submission:upload_or_get_cloud_path:71 - C:\Users\RISENG~1\AppData\Local\Temp\tmpq8_162q6\feature_conf/ is uploaded to location: abfss://rifeathrfs@rifeathrdls.dfs.core.windows.net/feathr_project/auto_generated_anchored_features.conf,abfss://rifeathrfs@rifeathrdls.dfs.core.windows.net/feathr_project/auto_generated_derived_features.conf,abfss://rifeathrfs@rifeathrdls.dfs.core.windows.net/feathr_project/auto_generated_request_features.conf
# 2022-12-01 17:13:54.879 | INFO     | feathr.utils._envvariableutil:get_environment_variable:82 - ADLS_ACCOUNT is not set in the environment variables.
# 2022-12-01 17:13:54.881 | INFO     | feathr.utils._envvariableutil:get_environment_variable:82 - ADLS_KEY is not set in the environment variables.
# 2022-12-01 17:13:54.883 | INFO     | feathr.utils._envvariableutil:get_environment_variable:82 - BLOB_ACCOUNT is not set in the environment variables.
# 2022-12-01 17:13:54.884 | INFO     | feathr.utils._envvariableutil:get_environment_variable:82 - BLOB_KEY is not set in the environment variables.
# 2022-12-01 17:13:54.885 | INFO     | feathr.spark_provider._synapse_submission:submit_feathr_job:118 - Main JAR file is not set, using default package 'com.linkedin.feathr:feathr_2.12:0.9.0' from Maven
# 2022-12-01 17:13:55.734 | INFO     | feathr.spark_provider._synapse_submission:submit_feathr_job:167 - See submitted job here: https://web.azuresynapse.net/en-us/monitoring/sparkapplication
# 2022-12-01 17:13:55.945 | INFO     | feathr.spark_provider._synapse_submission:wait_for_completion:177 - Current Spark job status: not_started
# 2022-12-01 17:14:26.078 | INFO     | feathr.spark_provider._synapse_submission:wait_for_completion:177 - Current Spark job status: starting
# 2022-12-01 17:14:56.199 | INFO     | feathr.spark_provider._synapse_submission:wait_for_completion:177 - Current Spark job status: starting
# 2022-12-01 17:15:26.348 | INFO     | feathr.spark_provider._synapse_submission:wait_for_completion:177 - Current Spark job status: running
# 2022-12-01 17:15:56.519 | INFO     | feathr.spark_provider._synapse_submission:wait_for_completion:177 - Current Spark job status: running
# 2022-12-01 17:16:26.664 | INFO     | feathr.spark_provider._synapse_submission:wait_for_completion:177 - Current Spark job status: running
# 2022-12-01 17:16:56.777 | INFO     | feathr.spark_provider._synapse_submission:wait_for_completion:177 - Current Spark job status: running
# 2022-12-01 17:17:26.882 | INFO     | feathr.spark_provider._synapse_submission:wait_for_completion:177 - Current Spark job status: success

# %% [markdown]
# Download the result and show the result
#
# Let's use the helper function `get_result_df` to download the result and view it:

# %%
def get_result_df(client: FeathrClient) -> pd.DataFrame:
    """Download the job result dataset from cloud as a Pandas dataframe."""
    res_url = feathr_client.get_job_result_uri(block=True, timeout_sec=600)
    tmp_dir = tempfile.TemporaryDirectory()
    feathr_client.feathr_spark_launcher.download_result(result_path=res_url, local_folder=tmp_dir.name)
    dataframe_list = []
    # assuming the result are in avro format
    for file in glob.glob(os.path.join(tmp_dir.name, '*.avro')):
        dataframe_list.append(pdx.read_avro(file))
    vertical_concat_df = pd.concat(dataframe_list, axis=0)
    tmp_dir.cleanup()
    return vertical_concat_df

df_res = get_result_df(client)
df_res
# Out:
# 2022-12-01 17:18:15.423 | INFO     | feathr.spark_provider._synapse_submission:wait_for_completion:177 - Current Spark job status: success
# 2022-12-01 17:18:15.553 | INFO     | feathr.spark_provider._synapse_submission:download_file:430 - Beginning reading of results from abfss://rifeathrfs@rifeathrdls.dfs.core.windows.net/feathr_output
# Downloading result files: 100%|██████████| 146/146 [02:04<00:00,  1.17it/s]
# 2022-12-01 17:20:58.594 | INFO     | feathr.spark_provider._synapse_submission:download_file:459 - Finish downloading files from abfss://rifeathrfs@rifeathrdls.dfs.core.windows.net/feathr_output to C:\Users\RISENG~1\AppData\Local\Temp\tmpg9b7cyye.
#      trip_id VendorID lpep_pickup_datetime lpep_dropoff_datetime  \
# 0      25281      NaN  2020-04-03 07:58:00   2020-04-03 08:26:00
# 1      26724      NaN  2020-04-07 22:45:00   2020-04-07 23:08:00
# 2       6453      2.0  2020-04-08 04:09:53   2020-04-08 04:27:48
# 3       8885      1.0  2020-04-10 21:33:57   2020-04-10 22:00:11
# 4      27764      NaN  2020-04-10 21:33:57   2020-04-10 22:00:11
# ..       ...      ...                  ...                   ...
# 219    35356      NaN  2020-04-30 16:12:00   2020-04-30 17:16:00
# 220    35424      NaN  2020-04-30 17:05:00   2020-04-30 17:25:00
# 221    24371      2.0  2020-04-30 18:09:34   2020-04-30 18:20:12
# 222    35458      NaN  2020-04-30 18:13:00   2020-04-30 18:25:00
# 223    24452      2.0  2020-04-30 21:29:56   2020-04-30 21:30:33
#
#     store_and_fwd_flag RatecodeID  PULocationID  DOLocationID passenger_count  \
# 0                 None        NaN            47           125             NaN
# 1                 None        NaN           228           125             NaN
# 2                    N        1.0            75           125             1.0
# 3                    N        1.0            89           125             1.0
# 4                 None        NaN            89           125             NaN
# ..                 ...        ...           ...           ...             ...
# 219               None        NaN            55           119             NaN
# 220               None        NaN           242           119             NaN
# 221                  N        5.0            74           119             1.0
# 222               None        NaN           127           119             NaN
# 223                  N        1.0           119           119             1.0
#
#      trip_distance  ...  ehail_fee  improvement_surcharge  total_amount  \
# 0            12.98  ...       None                    0.3         32.00
# 1             7.13  ...       None                    0.3         31.58
# 2             5.93  ...       None                    0.3         25.05
# 3             0.00  ...       None                    0.3         29.90
# 4             0.00  ...       None                    0.3         31.90
# ..             ...  ...        ...                    ...           ...
# 219          25.74  ...       None                    0.3         68.85
# 220           6.89  ...       None                    0.3         21.27
# 221           2.98  ...       None                    0.3         13.30
# 222           2.39  ...       None                    0.3         13.54
# 223           0.00  ...       None                    0.3          3.80
#
#      payment_type  trip_type congestion_surcharge  f_is_long_trip_distance  \
# 0             NaN        NaN                  NaN                    False
# 1             NaN        NaN                  NaN                    False
# 2             1.0        1.0                 2.75                    False
# 3             1.0        1.0                  2.5                    False
# 4             NaN        NaN                  NaN                    False
# ..            ...        ...                  ...                      ...
# 219           NaN        NaN                  NaN                    False
# 220           NaN        NaN                  NaN                    False
# 221           2.0        2.0                  0.0                    False
# 222           NaN        NaN                  NaN                    False
# 223           2.0        1.0                  0.0                    False
#
#      f_location_total_fare_cents f_location_avg_fare f_trip_time_rounded
# 0                         3170.0           31.700001                   8
# 1                         6023.0           30.115002                   3
# 2                         7923.0           26.410002                   7
# 3                        12363.0           24.726002                   6
# 4                        12363.0           24.726002                   6
# ..                           ...                 ...                 ...
# 219                     337156.0           15.325272                   4
# 220                     338978.0           15.338370                   0
# 221                     340278.0           15.327837                   0
# 222                     341327.0           15.306143                   2
# 223                     341577.0           15.248972                   0
#
# [35612 rows x 25 columns]

# %% [markdown]
# ## Materialize feature value into offline/online storage (e.g usage during: ML model inference path)
#
# While Feathr can compute the feature value from the feature definition on-the-fly at request time, it can also pre-compute
# and materialize the feature value to offline and/or online storage.
#
# We can push the generated features to the online store like below:

# %%
from feathr import JdbcSink

backfill_time = BackfillTime(start=datetime(2020, 5, 20), end=datetime(2020, 5, 20), step=timedelta(days=1))

redisSink = RedisSink(table_name="nyctaxi")

name = 'nyctaxifeatures'
SQLSink = JdbcSink(name, "jdbc:sqlserver://rifeathrdbserver.database.windows.net:1433;database=rifeathrdb;", "dbo.nyctaxifs", "USERPASS")

# os.environ[f"{name.upper()}_USER"] = "sqladmin"
# os.environ[f"{name.upper()}_PASSWORD"] = "ThisIsNotVerySecure!"

settings = MaterializationSettings(name="nycTaxiFeatures",
                                   backfill_time=backfill_time,
                                   sinks=[SQLSink],
                                   feature_names=["f_location_avg_fare", "f_location_max_fare"])

feathr_client.materialize_features(settings)
feathr_client.wait_job_to_finish(timeout_sec=500)
# Out:
# 2022-12-02 07:53:45.949 | INFO     | feathr.spark_provider._synapse_submission:upload_or_get_cloud_path:67 - Uploading C:\Users\RISENG~1\AppData\Local\Temp\tmp4sb7txp9\feathr_pyspark_driver.py to cloud..
# 2022-12-02 07:53:45.951 | INFO     | feathr.spark_provider._synapse_submission:upload_file:412 - Uploading file feathr_pyspark_driver.py
# 2022-12-02 07:54:25.574 | INFO     | feathr.spark_provider._synapse_submission:upload_file:418 - C:\Users\RISENG~1\AppData\Local\Temp\tmp4sb7txp9\feathr_pyspark_driver.py is uploaded to location: abfss://rifeathrfs@rifeathrdls.dfs.core.windows.net/feathr_project/feathr_pyspark_driver.py
# 2022-12-02 07:54:25.574 | INFO     | feathr.spark_provider._synapse_submission:upload_or_get_cloud_path:71 - C:\Users\RISENG~1\AppData\Local\Temp\tmp4sb7txp9\feathr_pyspark_driver.py is uploaded to location: abfss://rifeathrfs@rifeathrdls.dfs.core.windows.net/feathr_project/feathr_pyspark_driver.py
# 2022-12-02 07:54:25.574 | INFO     | feathr.utils._envvariableutil:get_environment_variable:82 - KAFKA_SASL_JAAS_CONFIG is not set in the environment variables.
# 2022-12-02 07:54:25.574 | INFO     | feathr.spark_provider._synapse_submission:upload_or_get_cloud_path:67 - Uploading C:\Users\RISENG~1\AppData\Local\Temp\tmp4sb7txp9\feature_gen_conf\auto_gen_config_1589925600.0.conf to cloud..
# 2022-12-02 07:54:25.592 | INFO     | feathr.spark_provider._synapse_submission:upload_file:412 - Uploading file auto_gen_config_1589925600.0.conf
# 2022-12-02 07:54:25.937 | INFO     | feathr.spark_provider._synapse_submission:upload_file:418 - C:\Users\RISENG~1\AppData\Local\Temp\tmp4sb7txp9\feature_gen_conf\auto_gen_config_1589925600.0.conf is uploaded to location: abfss://rifeathrfs@rifeathrdls.dfs.core.windows.net/feathr_project/auto_gen_config_1589925600.0.conf
# 2022-12-02 07:54:25.937 | INFO     | feathr.spark_provider._synapse_submission:upload_or_get_cloud_path:71 - C:\Users\RISENG~1\AppData\Local\Temp\tmp4sb7txp9\feature_gen_conf\auto_gen_config_1589925600.0.conf is uploaded to location: abfss://rifeathrfs@rifeathrdls.dfs.core.windows.net/feathr_project/auto_gen_config_1589925600.0.conf
# 2022-12-02 07:54:25.937 | INFO     | feathr.spark_provider._synapse_submission:upload_or_get_cloud_path:67 - Uploading C:\Users\RISENG~1\AppData\Local\Temp\tmp4sb7txp9\feature_conf/ to cloud..
# 2022-12-02 07:54:25.951 | INFO     | feathr.spark_provider._synapse_submission:upload_file_to_workdir:400 - Uploading folder C:\Users\RISENG~1\AppData\Local\Temp\tmp4sb7txp9\feature_conf/
# 2022-12-02 07:54:25.958 | INFO     | feathr.spark_provider._synapse_submission:upload_file:412 - Uploading file auto_generated_anchored_features.conf
# 2022-12-02 07:54:26.319 | INFO     | feathr.spark_provider._synapse_submission:upload_file:418 - C:\Users\risengupta\AppData\Local\Temp\tmp4sb7txp9\feature_conf\auto_generated_anchored_features.conf is uploaded to location: abfss://rifeathrfs@rifeathrdls.dfs.core.windows.net/feathr_project/auto_generated_anchored_features.conf
# 2022-12-02 07:54:26.323 | INFO     | feathr.spark_provider._synapse_submission:upload_file:412 - Uploading file auto_generated_derived_features.conf
# 2022-12-02 07:54:26.682 | INFO     | feathr.spark_provider._synapse_submission:upload_file:418 - C:\Users\risengupta\AppData\Local\Temp\tmp4sb7txp9\feature_conf\auto_generated_derived_features.conf is uploaded to location: abfss://rifeathrfs@rifeathrdls.dfs.core.windows.net/feathr_project/auto_generated_derived_features.conf
# 2022-12-02 07:54:26.686 | INFO     | feathr.spark_provider._synapse_submission:upload_file:412 - Uploading file auto_generated_request_features.conf
# 2022-12-02 07:54:27.009 | INFO     | feathr.spark_provider._synapse_submission:upload_file:418 - C:\Users\risengupta\AppData\Local\Temp\tmp4sb7txp9\feature_conf\auto_generated_request_features.conf is uploaded to location: abfss://rifeathrfs@rifeathrdls.dfs.core.windows.net/feathr_project/auto_generated_request_features.conf
# 2022-12-02 07:54:27.012 | INFO     | feathr.spark_provider._synapse_submission:upload_or_get_cloud_path:71 - C:\Users\RISENG~1\AppData\Local\Temp\tmp4sb7txp9\feature_conf/ is uploaded to location: abfss://rifeathrfs@rifeathrdls.dfs.core.windows.net/feathr_project/auto_generated_anchored_features.conf,abfss://rifeathrfs@rifeathrdls.dfs.core.windows.net/feathr_project/auto_generated_derived_features.conf,abfss://rifeathrfs@rifeathrdls.dfs.core.windows.net/feathr_project/auto_generated_request_features.conf
# 2022-12-02 07:54:27.014 | INFO     | feathr.utils._envvariableutil:get_environment_variable:82 - REDIS_PASSWORD is not set in the environment variables.
# 2022-12-02 07:54:27.016 | INFO     | feathr.utils._envvariableutil:get_environment_variable:82 - ADLS_ACCOUNT is not set in the environment variables.
# 2022-12-02 07:54:27.019 | INFO     | feathr.utils._envvariableutil:get_environment_variable:82 - ADLS_KEY is not set in the environment variables.
# 2022-12-02 07:54:27.021 | INFO     | feathr.utils._envvariableutil:get_environment_variable:82 - BLOB_ACCOUNT is not set in the environment variables.
# 2022-12-02 07:54:27.024 | INFO     | feathr.utils._envvariableutil:get_environment_variable:82 - BLOB_KEY is not set in the environment variables.
# 2022-12-02 07:54:27.043 | INFO     | feathr.utils._envvariableutil:get_environment_variable_with_default:51 - monitoring__database__sql__url not found in the config file.
# 2022-12-02 07:54:27.051 | INFO     | feathr.utils._envvariableutil:get_environment_variable_with_default:51 - monitoring__database__sql__user not found in the config file.
# 2022-12-02 07:54:27.056 | INFO     | feathr.utils._envvariableutil:get_environment_variable:82 - MONITORING_DATABASE_SQL_PASSWORD is not set in the environment variables.
# 2022-12-02 07:54:27.068 | INFO     | feathr.utils._envvariableutil:get_environment_variable_with_default:51 - NYCTAXIFEATURES_USER not found in the config file.
# 2022-12-02 07:54:27.073 | INFO     | feathr.utils._envvariableutil:get_environment_variable_with_default:51 - NYCTAXIFEATURES_PASSWORD not found in the config file.
# 2022-12-02 07:54:27.073 | INFO     | feathr.spark_provider._synapse_submission:submit_feathr_job:118 - Main JAR file is not set, using default package 'com.linkedin.feathr:feathr_2.12:0.9.0' from Maven
# 2022-12-02 07:54:30.289 | INFO     | feathr.spark_provider._synapse_submission:submit_feathr_job:167 - See submitted job here: https://web.azuresynapse.net/en-us/monitoring/sparkapplication
# 2022-12-02 07:54:30.388 | INFO     | feathr.spark_provider._synapse_submission:wait_for_completion:177 - Current Spark job status: not_started
# 2022-12-02 07:55:00.552 | INFO     | feathr.spark_provider._synapse_submission:wait_for_completion:177 - Current Spark job status: not_started
# 2022-12-02 07:55:30.662 | INFO     | feathr.spark_provider._synapse_submission:wait_for_completion:177 - Current Spark job status: not_started
# 2022-12-02 07:56:00.822 | INFO     | feathr.spark_provider._synapse_submission:wait_for_completion:177 - Current Spark job status: not_started
# 2022-12-02 07:56:30.966 | INFO     | feathr.spark_provider._synapse_submission:wait_for_completion:177 - Current Spark job status: starting
# 2022-12-02 07:57:01.101 | INFO     | feathr.spark_provider._synapse_submission:wait_for_completion:177 - Current Spark job status: starting
# 2022-12-02 07:57:31.266 | INFO     | feathr.spark_provider._synapse_submission:wait_for_completion:177 - Current Spark job status: starting
# 2022-12-02 07:58:01.509 | INFO     | feathr.spark_provider._synapse_submission:wait_for_completion:177 - Current Spark job status: starting
# 2022-12-02 07:58:31.655 | INFO     | feathr.spark_provider._synapse_submission:wait_for_completion:177 - Current Spark job status: starting
# 2022-12-02 07:59:01.783 | INFO     | feathr.spark_provider._synapse_submission:wait_for_completion:177 - Current Spark job status: running
# 2022-12-02 07:59:31.916 | INFO     | feathr.spark_provider._synapse_submission:wait_for_completion:177 - Current Spark job status: running
# 2022-12-02 08:00:02.116 | INFO     | feathr.spark_provider._synapse_submission:wait_for_completion:177 - Current Spark job status: dead
# 2022-12-02 08:00:02.116 | ERROR    | feathr.spark_provider._synapse_submission:wait_for_completion:181 - Feathr job has failed.
# 2022-12-02 08:00:06.082 | ERROR    | feathr.spark_provider._synapse_submission:wait_for_completion:183 -
# 22/12/02 06:58:11 INFO SignalUtils: Registering signal handler for TERM
# 22/12/02 06:58:11 INFO SignalUtils: Registering signal handler for HUP
# 22/12/02 06:58:11 INFO SignalUtils: Registering signal handler for INT
# 22/12/02 06:58:12 INFO SecurityManager: Changing view acls to: trusted-service-user
# 22/12/02 06:58:12 INFO SecurityManager: Changing modify acls to: trusted-service-user
# 22/12/02 06:58:12 INFO SecurityManager: Changing view acls groups to:
# 22/12/02 06:58:12 INFO SecurityManager: Changing modify acls groups to:
# 22/12/02 06:58:12 INFO SecurityManager: SecurityManager: authentication disabled; ui acls disabled; users  with view permissions: Set(trusted-service-user); groups with view permissions: Set(); users  with modify permissions: Set(trusted-service-user); groups with modify permissions: Set()
# 22/12/02 06:58:13 INFO ApplicationMaster: ApplicationAttemptId: appattempt_1669964176537_0001_000001
# 22/12/02 06:58:13 INFO ApplicationMaster: Starting the user application in a separate Thread
# 22/12/02 06:58:13 INFO ApplicationMaster: Waiting for spark context initialization...
# 22/12/02 06:58:13 INFO PythonRunner$: Initialized PythonRunnerOutputStream plugin org.apache.spark.microsoft.tools.api.plugin.MSToolsPythonRunnerOutputStreamPlugin.
# 22/12/02 06:58:13 INFO MetricsConfig: Loaded properties from hadoop-metrics2.properties
# 22/12/02 06:58:13 INFO MetricsSystemImpl: Scheduled Metric snapshot period at 10 second(s).
# 22/12/02 06:58:13 INFO MetricsSystemImpl: azure-file-system metrics system started
# 22/12/02 06:58:19 INFO SparkContext: Running Spark version 3.1.3.5.0-73073920
# 22/12/02 06:58:19 INFO ResourceUtils: ==============================================================
# 22/12/02 06:58:19 INFO ResourceUtils: No custom resources configured for spark.driver.
# 22/12/02 06:58:19 INFO ResourceUtils: ==============================================================
# 22/12/02 06:58:19 INFO SparkContext: Submitted application: FeathrPyspark
# 22/12/02 06:58:20 INFO ResourceProfile: Default ResourceProfile created, executor resources: Map(memoryOverhead -> name: memoryOverhead, amount: 384, script: , vendor: , cores -> name: cores, amount: 4, script: , vendor: , memory -> name: memory, amount: 28672, script: , vendor: , offHeap -> name: offHeap, amount: 0, script: , vendor: ), task resources: Map(cpus -> name: cpus, amount: 1.0)
# 22/12/02 06:58:20 INFO ResourceProfile: Limiting resource is cpus at 4 tasks per executor
# 22/12/02 06:58:20 INFO ResourceProfileManager: Added ResourceProfile id: 0
# 22/12/02 06:58:20 INFO SecurityManager: Changing view acls to: trusted-service-user
# 22/12/02 06:58:20 INFO SecurityManager: Changing modify acls to: trusted-service-user
# 22/12/02 06:58:20 INFO SecurityManager: Changing view acls groups to:
# 22/12/02 06:58:20 INFO SecurityManager: Changing modify acls groups to:
# 22/12/02 06:58:20 INFO SecurityManager: SecurityManager: authentication disabled; ui acls disabled; users  with view permissions: Set(trusted-service-user); groups with view permissions: Set(); users  with modify permissions: Set(trusted-service-user); groups with modify permissions: Set()
# 22/12/02 06:58:21 INFO Utils: Successfully started service 'sparkDriver' on port 45647.
# 22/12/02 06:58:21 INFO SparkEnv: Registering MapOutputTracker
# 22/12/02 06:58:21 INFO SparkEnv: Registering BlockManagerMaster
# 22/12/02 06:58:21 INFO BlockManagerMasterEndpoint: Using org.apache.spark.storage.DefaultTopologyMapper for getting topology information
# 22/12/02 06:58:21 INFO BlockManagerMasterEndpoint: BlockManagerMasterEndpoint up
# 22/12/02 06:58:21 INFO SparkEnv: Registering BlockManagerMasterHeartbeat
# 22/12/02 06:58:21 INFO DiskBlockManager: Created local directory at /mnt/var/hadoop/tmp/nm-local-dir/usercache/trusted-service-user/appcache/application_1669964176537_0001/blockmgr-ee0cf37f-fc6a-47eb-9592-a2be354feb5e
# 22/12/02 06:58:21 INFO MemoryStore: MemoryStore started with capacity 14.8 GiB
# 22/12/02 06:58:21 INFO SparkEnv: Registering OutputCommitCoordinator
# 22/12/02 06:58:21 INFO log: Logging initialized @26604ms to org.sparkproject.jetty.util.log.Slf4jLog
# 22/12/02 06:58:21 INFO Server: jetty-9.4.40.v20210413; built: 2021-04-13T20:42:42.668Z; git: b881a572662e1943a14ae12e7e1207989f218b74; jvm 1.8.0_342-8u342-b07-0ubuntu1~18.04-b07
# 22/12/02 06:58:21 INFO Server: Started @26849ms
# 22/12/02 06:58:22 INFO AbstractConnector: Started ServerConnector@3c9c8e13{HTTP/1.1, (http/1.1)}{0.0.0.0:35263}
# 22/12/02 06:58:22 INFO Utils: Successfully started service 'SparkUI' on port 35263.
# 22/12/02 06:58:22 INFO ServerInfo: Adding filter to /jobs: org.apache.hadoop.yarn.server.webproxy.amfilter.AmIpFilter
# 22/12/02 06:58:22 INFO ContextHandler: Started o.s.j.s.ServletContextHandler@5b0d4838{/jobs,null,AVAILABLE,@Spark}
# 22/12/02 06:58:22 INFO ServerInfo: Adding filter to /jobs/json: org.apache.hadoop.yarn.server.webproxy.amfilter.AmIpFilter
# 22/12/02 06:58:22 INFO ContextHandler: Started o.s.j.s.ServletContextHandler@2241ef51{/jobs/json,null,AVAILABLE,@Spark}
# 22/12/02 06:58:22 INFO ServerInfo: Adding filter to /jobs/job: org.apache.hadoop.yarn.server.webproxy.amfilter.AmIpFilter
# 22/12/02 06:58:22 INFO ContextHandler: Started o.s.j.s.ServletContextHandler@72761043{/jobs/job,null,AVAILABLE,@Spark}
# 22/12/02 06:58:22 INFO ServerInfo: Adding filter to /jobs/job/json: org.apache.hadoop.yarn.server.webproxy.amfilter.AmIpFilter
# 22/12/02 06:58:22 INFO ContextHandler: Started o.s.j.s.ServletContextHandler@65869652{/jobs/job/json,null,AVAILABLE,@Spark}
# 22/12/02 06:58:22 INFO ServerInfo: Adding filter to /stages: org.apache.hadoop.yarn.server.webproxy.amfilter.AmIpFilter
# 22/12/02 06:58:22 INFO ContextHandler: Started o.s.j.s.ServletContextHandler@18794e75{/stages,null,AVAILABLE,@Spark}
# 22/12/02 06:58:22 INFO ServerInfo: Adding filter to /stages/json: org.apache.hadoop.yarn.server.webproxy.amfilter.AmIpFilter
# 22/12/02 06:58:22 INFO ContextHandler: Started o.s.j.s.ServletContextHandler@4ae51182{/stages/json,null,AVAILABLE,@Spark}
# 22/12/02 06:58:22 INFO ServerInfo: Adding filter to /stages/stage: org.apache.hadoop.yarn.server.webproxy.amfilter.AmIpFilter
# 22/12/02 06:58:22 INFO ContextHandler: Started o.s.j.s.ServletContextHandler@2dc33285{/stages/stage,null,AVAILABLE,@Spark}
# 22/12/02 06:58:22 INFO ServerInfo: Adding filter to /stages/stage/json: org.apache.hadoop.yarn.server.webproxy.amfilter.AmIpFilter
# 22/12/02 06:58:22 INFO ContextHandler: Started o.s.j.s.ServletContextHandler@27444f2e{/stages/stage/json,null,AVAILABLE,@Spark}
# 22/12/02 06:58:22 INFO ServerInfo: Adding filter to /stages/pool: org.apache.hadoop.yarn.server.webproxy.amfilter.AmIpFilter
# 22/12/02 06:58:22 INFO ContextHandler: Started o.s.j.s.ServletContextHandler@33cd8106{/stages/pool,null,AVAILABLE,@Spark}
# 22/12/02 06:58:22 INFO ServerInfo: Adding filter to /stages/pool/json: org.apache.hadoop.yarn.server.webproxy.amfilter.AmIpFilter
# 22/12/02 06:58:22 INFO ContextHandler: Started o.s.j.s.ServletContextHandler@34e070fc{/stages/pool/json,null,AVAILABLE,@Spark}
# 22/12/02 06:58:22 INFO ServerInfo: Adding filter to /storage: org.apache.hadoop.yarn.server.webproxy.amfilter.AmIpFilter
# 22/12/02 06:58:22 INFO ContextHandler: Started o.s.j.s.ServletContextHandler@3c99561d{/storage,null,AVAILABLE,@Spark}
# 22/12/02 06:58:22 INFO ServerInfo: Adding filter to /storage/json: org.apache.hadoop.yarn.server.webproxy.amfilter.AmIpFilter
# 22/12/02 06:58:22 INFO ContextHandler: Started o.s.j.s.ServletContextHandler@3001c4fa{/storage/json,null,AVAILABLE,@Spark}
# 22/12/02 06:58:22 INFO ServerInfo: Adding filter to /storage/rdd: org.apache.hadoop.yarn.server.webproxy.amfilter.AmIpFilter
# 22/12/02 06:58:22 INFO ContextHandler: Started o.s.j.s.ServletContextHandler@4730d56d{/storage/rdd,null,AVAILABLE,@Spark}
# 22/12/02 06:58:22 INFO ServerInfo: Adding filter to /storage/rdd/json: org.apache.hadoop.yarn.server.webproxy.amfilter.AmIpFilter
# 22/12/02 06:58:22 INFO ContextHandler: Started o.s.j.s.ServletContextHandler@79147dca{/storage/rdd/json,null,AVAILABLE,@Spark}
# 22/12/02 06:58:22 INFO ServerInfo: Adding filter to /environment: org.apache.hadoop.yarn.server.webproxy.amfilter.AmIpFilter
# 22/12/02 06:58:22 INFO ContextHandler: Started o.s.j.s.ServletContextHandler@b0acafa{/environment,null,AVAILABLE,@Spark}
# 22/12/02 06:58:22 INFO ServerInfo: Adding filter to /environment/json: org.apache.hadoop.yarn.server.webproxy.amfilter.AmIpFilter
# 22/12/02 06:58:22 INFO ContextHandler: Started o.s.j.s.ServletContextHandler@308be48{/environment/json,null,AVAILABLE,@Spark}
# 22/12/02 06:58:22 INFO ServerInfo: Adding filter to /executors: org.apache.hadoop.yarn.server.webproxy.amfilter.AmIpFilter
# 22/12/02 06:58:22 INFO ContextHandler: Started o.s.j.s.ServletContextHandler@797c6a1e{/executors,null,AVAILABLE,@Spark}
# 22/12/02 06:58:22 INFO ServerInfo: Adding filter to /executors/json: org.apache.hadoop.yarn.server.webproxy.amfilter.AmIpFilter
# 22/12/02 06:58:22 INFO ContextHandler: Started o.s.j.s.ServletContextHandler@13411db{/executors/json,null,AVAILABLE,@Spark}
# 22/12/02 06:58:22 INFO ServerInfo: Adding filter to /executors/threadDump: org.apache.hadoop.yarn.server.webproxy.amfilter.AmIpFilter
# 22/12/02 06:58:22 INFO ContextHandler: Started o.s.j.s.ServletContextHandler@494d9a44{/executors/threadDump,null,AVAILABLE,@Spark}
# 22/12/02 06:58:22 INFO ServerInfo: Adding filter to /executors/threadDump/json: org.apache.hadoop.yarn.server.webproxy.amfilter.AmIpFilter
# 22/12/02 06:58:22 INFO ContextHandler: Started o.s.j.s.ServletContextHandler@7bcf1bba{/executors/threadDump/json,null,AVAILABLE,@Spark}
# 22/12/02 06:58:22 INFO ServerInfo: Adding filter to /static: org.apache.hadoop.yarn.server.webproxy.amfilter.AmIpFilter
# 22/12/02 06:58:22 INFO ContextHandler: Started o.s.j.s.ServletContextHandler@6e2a7eeb{/static,null,AVAILABLE,@Spark}
# 22/12/02 06:58:22 INFO ServerInfo: Adding filter to /: org.apache.hadoop.yarn.server.webproxy.amfilter.AmIpFilter
# 22/12/02 06:58:22 INFO ContextHandler: Started o.s.j.s.ServletContextHandler@3caf512c{/,null,AVAILABLE,@Spark}
# 22/12/02 06:58:22 INFO ServerInfo: Adding filter to /api: org.apache.hadoop.yarn.server.webproxy.amfilter.AmIpFilter
# 22/12/02 06:58:22 INFO ContextHandler: Started o.s.j.s.ServletContextHandler@112fb755{/api,null,AVAILABLE,@Spark}
# 22/12/02 06:58:22 INFO ServerInfo: Adding filter to /metrics: org.apache.hadoop.yarn.server.webproxy.amfilter.AmIpFilter
# 22/12/02 06:58:22 INFO ContextHandler: Started o.s.j.s.ServletContextHandler@2c28a3bc{/metrics,null,AVAILABLE,@Spark}
# 22/12/02 06:58:22 INFO ServerInfo: Adding filter to /jobs/job/kill: org.apache.hadoop.yarn.server.webproxy.amfilter.AmIpFilter
# 22/12/02 06:58:22 INFO ContextHandler: Started o.s.j.s.ServletContextHandler@7bf3473f{/jobs/job/kill,null,AVAILABLE,@Spark}
# 22/12/02 06:58:22 INFO ServerInfo: Adding filter to /stages/stage/kill: org.apache.hadoop.yarn.server.webproxy.amfilter.AmIpFilter
# 22/12/02 06:58:22 INFO ContextHandler: Started o.s.j.s.ServletContextHandler@58d0d8f6{/stages/stage/kill,null,AVAILABLE,@Spark}
# 22/12/02 06:58:22 INFO SparkUI: Bound SparkUI to 0.0.0.0, and started at http://vm-e5260252:35263
# 22/12/02 06:58:22 INFO YarnClusterScheduler: Created YarnClusterScheduler
# 22/12/02 06:58:22 INFO Utils: Successfully started service 'org.apache.spark.network.netty.NettyBlockTransferService' on port 43013.
# 22/12/02 06:58:22 INFO NettyBlockTransferService: Server created on vm-e5260252:43013
# 22/12/02 06:58:22 INFO BlockManager: Using org.apache.spark.storage.RandomBlockReplicationPolicy for block replication policy
# 22/12/02 06:58:22 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, vm-e5260252, 43013, None)
# 22/12/02 06:58:22 INFO BlockManagerMasterEndpoint: Registering block manager vm-e5260252:43013 with 14.8 GiB RAM, BlockManagerId(driver, vm-e5260252, 43013, None)
# 22/12/02 06:58:22 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, vm-e5260252, 43013, None)
# 22/12/02 06:58:22 INFO BlockManager: external shuffle service port = 7337
# 22/12/02 06:58:22 INFO BlockManager: Initialized BlockManager: BlockManagerId(driver, vm-e5260252, 43013, None)
# 22/12/02 06:58:22 INFO SparkObservabilityBus: SparkDiagnosticEmitter: ShoeboxEmitter initialized
# 22/12/02 06:58:22 INFO ServerInfo: Adding filter to /metrics/json: org.apache.hadoop.yarn.server.webproxy.amfilter.AmIpFilter
# 22/12/02 06:58:22 INFO ContextHandler: Started o.s.j.s.ServletContextHandler@4bc8e15c{/metrics/json,null,AVAILABLE,@Spark}
# 22/12/02 06:58:22 INFO ServerInfo: Adding filter to /metrics/prometheus: org.apache.hadoop.yarn.server.webproxy.amfilter.AmIpFilter
# 22/12/02 06:58:22 INFO ContextHandler: Started o.s.j.s.ServletContextHandler@f4799f{/metrics/prometheus,null,AVAILABLE,@Spark}
# 22/12/02 06:58:23 INFO SingleEventLogFileWriter: Logging events to wasbs://d7f295d5-e18a-4c2b-b25e-b7cc62ab880a@h93saq1dkd00l0essko9khde.blob.core.windows.net/events/15/eventLogs/application_1669964176537_0001_1.inprogress
# 22/12/02 06:58:23 INFO EnhancementLiveStatusPlugin: Enhancement Live App Status Plugin initialization
# 22/12/02 06:58:23 INFO EnhancementLiveStatusPlugin: Live app enhancement was enabled
# 22/12/02 06:58:23 INFO EnhancementAppStatusListener: attach Enhancement AppStatus Listener on live application
# 22/12/02 06:58:23 INFO DataOperations: configuration: spark.data.maxRecords: 1000
# 22/12/02 06:58:24 INFO SparkContext: Registered live app status plugin org.apache.spark.ui.EnhancementLiveStatusPlugin
# 22/12/02 06:58:24 INFO SparkContext: Registered live app status plugin org.apache.spark.diagnostic.synapse.SparkDiagnosticPlugin
# 22/12/02 06:58:24 INFO RpcAppSparkContextServer: Opening remote SparkContext service at 10.0.32.5:18083, remoteSparkContext/remoteSparkContextEndpoint
# 22/12/02 06:58:24 INFO RemoteSparkContextServer: Opening remote SparkContext server
# 22/12/02 06:58:24 INFO SecurityManager: Changing view acls to: trusted-service-user
# 22/12/02 06:58:24 INFO SecurityManager: Changing modify acls to: trusted-service-user
# 22/12/02 06:58:24 INFO SecurityManager: Changing view acls groups to:
# 22/12/02 06:58:24 INFO SecurityManager: Changing modify acls groups to:
# 22/12/02 06:58:24 INFO SecurityManager: SecurityManager: authentication disabled; ui acls disabled; users  with view permissions: Set(trusted-service-user); groups with view permissions: Set(); users  with modify permissions: Set(trusted-service-user); groups with modify permissions: Set()
# 22/12/02 06:58:24 INFO Utils: Successfully started service 'remoteSparkContext' on port 18083.
# 22/12/02 06:58:24 INFO RemoteSparkContextServer: Will serve remote SparkContext on 10.0.32.5:18083, remoteSparkContext/remoteSparkContextEndpoint
# 22/12/02 06:58:25 INFO RpcAppListener: Got host of RPC history server from node info: vm-e1b24897
# 22/12/02 06:58:25 INFO RpcAppSender: Opening RPC app sender
# 22/12/02 06:58:25 INFO SecurityManager: Changing view acls to: trusted-service-user
# 22/12/02 06:58:25 INFO SecurityManager: Changing modify acls to: trusted-service-user
# 22/12/02 06:58:25 INFO SecurityManager: Changing view acls groups to:
# 22/12/02 06:58:25 INFO SecurityManager: Changing modify acls groups to:
# 22/12/02 06:58:25 INFO SecurityManager: SecurityManager: authentication disabled; ui acls disabled; users  with view permissions: Set(trusted-service-user); groups with view permissions: Set(); users  with modify permissions: Set(trusted-service-user); groups with modify permissions: Set()
# 22/12/02 06:58:25 INFO TransportClientFactory: Successfully created connection to vm-e1b24897/10.0.32.4:18082 after 19 ms (0 ms spent in bootstraps)
# 22/12/02 06:58:25 INFO RpcAppSender: Will send events to RPC history server at vm-e1b24897:18082, rpcHistoryServer/rpcHistoryServerEndpoint
# 22/12/02 06:58:25 INFO SparkContext: Registered live app status plugin org.apache.spark.deploy.history.rpc.app.RpcAppLivePlugin
# 22/12/02 06:58:25 INFO EventsWriter$: Using the default value false for spark.peregrine.log.disableAnon
# 22/12/02 06:58:25 INFO EventsWriter$: Using the default value false for spark.peregrine.log.prodOverride
# 22/12/02 06:58:25 INFO SparkContext: Registered listener com.microsoft.hdinsight.spark.metrics.SparkMetricsListener
# 22/12/02 06:58:25 INFO SparkContext: Registered listener com.microsoft.peregrine.spark.listeners.PeregrineListenerSynapse
# 22/12/02 06:58:25 INFO SparkContext: Registered listener org.apache.spark.listeners.LogAnalyticsSparkListener
# 22/12/02 06:58:25 INFO SparkContext: Registered listener com.microsoft.impulse.analyze.eventLog.ImpulseListener
# 22/12/02 06:58:25 INFO SparkContext: Registered listener com.microsoft.autotune.listener.AutotuneApplicationListener
# 22/12/02 06:58:26 INFO RequestHedgingRMFailoverProxyProvider: Created wrapped proxy for [rm1, rm2]
# 22/12/02 06:58:26 INFO YarnRMClient: Registering the ApplicationMaster
# 22/12/02 06:58:26 INFO RequestHedgingRMFailoverProxyProvider: Looking for the active RM in [rm1, rm2]...
# 22/12/02 06:58:26 INFO RequestHedgingRMFailoverProxyProvider: Found active RM [rm2]
# 22/12/02 06:58:26 INFO ApplicationMaster: Preparing Local resources
# 22/12/02 06:58:26 INFO ApplicationMaster:
# ===============================================================================
# Default YARN executor launch context:
#   env:
#     CLASSPATH -> /usr/lib/library-manager/bin/libraries/scala/*<CPS>{{PWD}}<CPS>{{PWD}}/__spark_conf__<CPS>{{PWD}}/__spark_libs__/*<CPS>/opt/spark/jars/*<CPS>$HADOOP_CONF_DIR<CPS>/usr/hdp/current/hadoop-client/*<CPS>/usr/hdp/current/hadoop-client/lib/*<CPS>/usr/hdp/current/hadoop-hdfs-client/*<CPS>/usr/hdp/current/hadoop-hdfs-client/lib/*<CPS>/usr/hdp/current/hadoop-yarn-client/*<CPS>/usr/hdp/current/hadoop-yarn-client/lib/*<CPS>$HADOOP_MAPRED_HOME/share/hadoop/mapreduce/*<CPS>$HADOOP_MAPRED_HOME/share/hadoop/mapreduce/lib/*<CPS>{{PWD}}/__spark_conf__/__hadoop_conf__
#     SPARK_YARN_STAGING_DIR -> wasbs://d7f295d5-e18a-4c2b-b25e-b7cc62ab880a@h93saq1dkd00l0essko9khde.blob.core.windows.net/user/trusted-service-user/trusted-service-user/.sparkStaging/application_1669964176537_0001
#     PATH -> /usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/snap/bin:/usr/local/cuda-11.5/bin:/home/trusted-service-user/cluster-env/env/bin
#     SPARK_USER -> trusted-service-user
#     SPARKR_INLINE_SESSION_LEVEL_ENABLE -> true
#     SPARK_HOME -> /opt/spark
#     PYTHONPATH -> /opt/spark/python/lib/pyspark.zip<CPS>/opt/spark/python/lib/py4j-0.10.7-src.zip<CPS>{{PWD}}/com.linkedin.feathr_feathr_2.12-0.9.0.jar<CPS>{{PWD}}/org.apache.xbean_xbean-asm6-shaded-4.10.jar<CPS>{{PWD}}/com.microsoft.azure_azure-eventhubs-spark_2.12-2.3.21.jar<CPS>{{PWD}}/org.apache.kafka_kafka-clients-3.1.0.jar<CPS>{{PWD}}/com.google.guava_guava-31.1-jre.jar<CPS>{{PWD}}/it.unimi.dsi_fastutil-8.1.1.jar<CPS>{{PWD}}/org.mvel_mvel2-2.2.8.Final.jar<CPS>{{PWD}}/com.fasterxml.jackson.module_jackson-module-scala_2.12-2.12.6.jar<CPS>{{PWD}}/com.fasterxml.jackson.dataformat_jackson-dataformat-yaml-2.12.6.jar<CPS>{{PWD}}/com.fasterxml.jackson.dataformat_jackson-dataformat-csv-2.12.6.jar<CPS>{{PWD}}/com.jasonclawson_jackson-dataformat-hocon-1.1.0.jar<CPS>{{PWD}}/com.redislabs_spark-redis_2.12-3.0.0.jar<CPS>{{PWD}}/com.google.protobuf_protobuf-java-2.6.1.jar<CPS>{{PWD}}/net.snowflake_snowflake-jdbc-3.13.18.jar<CPS>{{PWD}}/net.snowflake_spark-snowflake_2.12-2.10.0-spark_3.2.jar<CPS>{{PWD}}/org.apache.commons_commons-lang3-3.12.0.jar<CPS>{{PWD}}/org.xerial_sqlite-jdbc-3.36.0.3.jar<CPS>{{PWD}}/com.github.changvvb_jackson-module-caseclass_2.12-1.1.1.jar<CPS>{{PWD}}/com.azure.cosmos.spark_azure-cosmos-spark_3-1_2-12-4.11.1.jar<CPS>{{PWD}}/org.eclipse.jetty_jetty-util-9.3.24.v20180605.jar<CPS>{{PWD}}/com.microsoft.sqlserver_mssql-jdbc-10.2.0.jre8.jar<CPS>{{PWD}}/org.postgresql_postgresql-42.3.4.jar<CPS>{{PWD}}/com.microsoft.azure_azure-eventhubs-3.3.0.jar<CPS>{{PWD}}/org.scala-lang.modules_scala-java8-compat_2.12-0.9.0.jar<CPS>{{PWD}}/org.apache.qpid_proton-j-0.33.8.jar<CPS>{{PWD}}/com.microsoft.azure_qpid-proton-j-extensions-1.2.4.jar<CPS>{{PWD}}/com.microsoft.azure_azure-client-authentication-1.7.3.jar<CPS>{{PWD}}/com.nimbusds_nimbus-jose-jwt-9.8.1.jar<CPS>{{PWD}}/com.microsoft.azure_azure-client-runtime-1.7.3.jar<CPS>{{PWD}}/commons-codec_commons-codec-1.11.jar<CPS>{{PWD}}/com.microsoft.azure_adal4j-1.6.4.jar<CPS>{{PWD}}/com.microsoft.azure_azure-annotations-1.10.0.jar<CPS>{{PWD}}/com.microsoft.rest_client-runtime-1.7.3.jar<CPS>{{PWD}}/com.squareup.retrofit2_retrofit-2.7.2.jar<CPS>{{PWD}}/com.squareup.okhttp3_okhttp-3.12.6.jar<CPS>{{PWD}}/com.squareup.okhttp3_logging-interceptor-3.12.2.jar<CPS>{{PWD}}/com.squareup.okhttp3_okhttp-urlconnection-3.12.2.jar<CPS>{{PWD}}/com.squareup.retrofit2_converter-jackson-2.7.2.jar<CPS>{{PWD}}/com.fasterxml.jackson.datatype_jackson-datatype-joda-2.10.1.jar<CPS>{{PWD}}/io.reactivex_rxjava-1.3.8.jar<CPS>{{PWD}}/com.squareup.retrofit2_adapter-rxjava-2.7.2.jar<CPS>{{PWD}}/com.squareup.okio_okio-1.15.0.jar<CPS>{{PWD}}/joda-time_joda-time-2.9.9.jar<CPS>{{PWD}}/com.nimbusds_oauth2-oidc-sdk-6.5.jar<CPS>{{PWD}}/com.google.code.gson_gson-2.8.0.jar<CPS>{{PWD}}/com.sun.mail_javax.mail-1.6.1.jar<CPS>{{PWD}}/com.github.stephenc.jcip_jcip-annotations-1.0-1.jar<CPS>{{PWD}}/net.minidev_json-smart-2.3.jar<CPS>{{PWD}}/com.nimbusds_lang-tag-1.7.jar<CPS>{{PWD}}/javax.activation_activation-1.1.jar<CPS>{{PWD}}/net.minidev_accessors-smart-1.2.jar<CPS>{{PWD}}/org.ow2.asm_asm-5.0.4.jar<CPS>{{PWD}}/com.github.luben_zstd-jni-1.5.0-4.jar<CPS>{{PWD}}/org.lz4_lz4-java-1.8.0.jar<CPS>{{PWD}}/org.xerial.snappy_snappy-java-1.1.8.4.jar<CPS>{{PWD}}/com.google.guava_failureaccess-1.0.1.jar<CPS>{{PWD}}/com.google.guava_listenablefuture-9999.0-empty-to-avoid-conflict-with-guava.jar<CPS>{{PWD}}/com.google.code.findbugs_jsr305-3.0.2.jar<CPS>{{PWD}}/org.checkerframework_checker-qual-3.12.0.jar<CPS>{{PWD}}/com.google.errorprone_error_prone_annotations-2.11.0.jar<CPS>{{PWD}}/com.google.j2objc_j2objc-annotations-1.3.jar<CPS>{{PWD}}/com.fasterxml.jackson.core_jackson-core-2.12.6.jar<CPS>{{PWD}}/com.fasterxml.jackson.core_jackson-annotations-2.12.6.jar<CPS>{{PWD}}/com.fasterxml.jackson.core_jackson-databind-2.12.6.jar<CPS>{{PWD}}/com.thoughtworks.paranamer_paranamer-2.8.jar<CPS>{{PWD}}/org.yaml_snakeyaml-1.27.jar<CPS>{{PWD}}/com.typesafe_config-1.2.1.jar<CPS>{{PWD}}/org.apache.commons_commons-pool2-2.0.jar<CPS>{{PWD}}/redis.clients_jedis- ...
#
#   command:
#     LD_LIBRARY_PATH=\"/usr/hdp/current/hadoop-client/lib/native:/usr/lib/jvm/java-1.8.0-openjdk-amd64/jre/lib/amd64:/usr/lib/jvm/java-1.8.0-openjdk-amd64/jre/lib/amd64/server:$LD_LIBRARY_PATH\" \
#       {{JAVA_HOME}}/bin/java \
#       -server \
#       -Xmx28672m \
#       '-Detwlogger.component=sparkexecutor' \
#       '-DlogFilter.filename=SparkLogFilters.xml' \
#       '-DpatternGroup.filename=SparkPatternGroups.xml' \
#       '-Dlog4jspark.root.logger=INFO,console,RFA,ETW,Anonymizer' \
#       '-Dlog4jspark.log.dir=/var/log/sparkapp/\${user.name}' \
#       '-Dlog4jspark.log.file=sparkexecutor.log' \
#       '-Dlog4j.configuration=file:/usr/hdp/current/spark3-client/conf/executor-log4j.properties' \
#       '-Djavax.xml.parsers.SAXParserFactory=com.sun.org.apache.xerces.internal.jaxp.SAXParserFactoryImpl' \
#       '-XX:+UseG1GC' \
#       -Djava.io.tmpdir={{PWD}}/tmp \
#       '-Dspark.driver.port=45647' \
#       '-Dspark.synapse.history.rpc.port=18082' \
#       '-Dspark.history.ui.port=18080' \
#       '-Dspark.ui.port=0' \
#       -Dspark.yarn.app.container.log.dir=<LOG_DIR> \
#       -XX:OnOutOfMemoryError='kill %p' \
#       org.apache.spark.executor.YarnCoarseGrainedExecutorBackend \
#       --driver-url \
#       spark://CoarseGrainedScheduler@vm-e5260252:45647 \
#       --executor-id \
#       <executorId> \
#       --hostname \
#       <hostname> \
#       --cores \
#       4 \
#       --app-id \
#       application_1669964176537_0001 \
#       --resourceProfileId \
#       0 \
#       --user-class-path \
#       file:$PWD/__app__.jar \
#       --user-class-path \
#       file:$PWD/com.linkedin.feathr_feathr_2.12-0.9.0.jar \
#       --user-class-path \
#       file:$PWD/org.apache.xbean_xbean-asm6-shaded-4.10.jar \
#       --user-class-path \
#       file:$PWD/com.microsoft.azure_azure-eventhubs-spark_2.12-2.3.21.jar \
#       --user-class-path \
#       file:$PWD/org.apache.kafka_kafka-clients-3.1.0.jar \
#       --user-class-path \
#       file:$PWD/com.google.guava_guava-31.1-jre.jar \
#       --user-class-path \
#       file:$PWD/it.unimi.dsi_fastutil-8.1.1.jar \
#       --user-class-path \
#       file:$PWD/org.mvel_mvel2-2.2.8.Final.jar \
#       --user-class-path \
#       file:$PWD/com.fasterxml.jackson.module_jackson-module-scala_2.12-2.12.6.jar \
#       --user-class-path \
#       file:$PWD/com.fasterxml.jackson.dataformat_jackson-dataformat-yaml-2.12.6.jar \
#       --user-class-path \
#       file:$PWD/com.fasterxml.jackson.dataformat_jackson-dataformat-csv-2.12.6.jar \
#       --user-class-path \
#       file:$PWD/com.jasonclawson_jackson-dataformat-hocon-1.1.0.jar \
#       --user-class-path \
#       file:$PWD/com.redislabs_spark-redis_2.12-3.0.0.jar \
#       --user-class-path \
#       file:$PWD/com.google.protobuf_protobuf-java-2.6.1.jar \
#       --user-class-path \
#       file:$PWD/net.snowflake_snowflake-jdbc-3.13.18.jar \
#       --user-class-path \
#       file:$PWD/net.snowflake_spark-snowflake_2.12-2.10.0-spark_3.2.jar \
#       --user-class-path \
#       file:$PWD/org.apache.commons_commons-lang3-3.12.0.jar \
#       --user-class-path \
#       file:$PWD/org.xerial_sqlite-jdbc-3.36.0.3.jar \
#       --user-class-path \
#       file:$PWD/com.github.changvvb_jackson-module-caseclass_2.12-1.1.1.jar \
#       --user-class-path \
#       file:$PWD/com.azure.cosmos.spark_azure-cosmos-spark_3-1_2-12-4.11.1.jar \
#       --user-class-path \
#       file:$PWD/org.eclipse.jetty_jetty-util-9.3.24.v20180605.jar \
#       --user-class-path \
#       file:$PWD/com.microsoft.sqlserver_mssql-jdbc-10.2.0.jre8.jar \
#       --user-class-path \
#       file:$PWD/org.postgresql_postgresql-42.3.4.jar \
#       --user-class-path \
#       file:$PWD/com.microsoft.azure_azure-eventhubs-3.3.0.jar \
#       --user-class-path \
#       file:$PWD/org.scala-lang.modules_scala-java8-compat_2.12-0.9.0.jar \
#       --user-class-path \
#       file:$PWD/org.apache.qpid_proton-j-0.33.8.jar \
#       --user-class-path \
#       file:$PWD/com.microsoft.azure_qpid-proton-j-extensions-1.2.4.jar \
#       --user-class-path \
#       file:$PWD/com.microsoft.azure_azure-client-authentication-1.7.3.jar \
#       --user-class-path \
#       file:$PWD/com.nimbusds_nimbus-jose-jwt-9.8.1.jar \
#       --user-class-path \
#       file:$PWD/com.microsoft.azure_azure-client-runtime-1.7.3.jar \
#       --user-class-path \
#       file:$PWD/commons-codec_commons-codec-1.11.jar \
#       --user-class-path \
#       file:$PWD/com.microsoft.azure_adal4j-1.6.4.jar \
#       --user-class-path \
#       file:$PWD/com.microsoft.azure_azure-annotations-1.10.0.jar \
#       --user-class-path \
#       file:$PWD/com.microsoft.rest_client-runtime-1.7.3.jar \
#       --user-class-path \
#       file:$PWD/com.squareup.retrofit2_retrofit-2.7.2.jar \
#       --user-class-path \
#       file:$PWD/com.squareup.okhttp3_okhttp-3.12.6.jar \
#       --user-class-path \
#       file:$PWD/com.squareup.okhttp3_logging-interceptor-3.12.2.jar \
#       --user-class-path \
#       file:$PWD/com.squareup.okhttp3_okhttp-urlconnection-3.12.2.jar \
#       --user-class-path \
#       file:$PWD/com.squareup.retrofit2_converter-jackson-2.7.2.jar \
#       --user-class-path \
#       file:$PWD/com.fasterxml.jackson.datatype_jackson-datatype-joda-2.10.1.jar \
#       --user-class-path \
#       file:$PWD/io.reactivex_rxjava-1.3.8.jar \
#       --user-class-path \
#       file:$PWD/com.squareup.retrofit2_adapter-rxjava-2.7.2.jar \
#       --user-class-path \
#       file:$PWD/com.squareup.okio_okio-1.15.0.jar \
#       --user-class-path \
#       file:$PWD/joda-time_joda-time-2.9.9.jar \
#       --user-class-path \
#       file:$PWD/com.nimbusds_oauth2-oidc-sdk-6.5.jar \
#       --user-class-path \
#       file:$PWD/com.google.code.gson_gson-2.8.0.jar \
#       --user-class-path \
#       file:$PWD/com.sun.mail_javax.mail-1.6.1.jar \
#       --user-class-path \
#       file:$PWD/com.github.stephenc.jcip_jcip-annotations-1.0-1.jar \
#       --user-class-path \
#       file:$PWD/net.minidev_json-smart-2.3.jar \
#       --user-class-path \
#       file:$PWD/com.nimbusds_lang-tag-1.7.jar \
#       --user-class-path \
#       file:$PWD/javax.activation_activation-1.1.jar \
#       --user-class-path \
#       file:$PWD/net.minidev_accessors-smart-1.2.jar \
#       --user-class-path \
#       file:$PWD/org.ow2.asm_asm-5.0.4.jar \
#       --user-class-path \
#       file:$PWD/com.github.luben_zstd-jni-1.5.0-4.jar \
#       --user-class-path \
#       file:$PWD/org.lz4_lz4-java-1.8.0.jar \
#       --user-class-path \
#       file:$PWD/org.xerial.snappy_snappy-java-1.1.8.4.jar \
#       --user-class-path \
#       file:$PWD/com.google.guava_failureaccess-1.0.1.jar \
#       --user-class-path \
#       file:$PWD/com.google.guava_listenablefuture-9999.0-empty-to-avoid-conflict-with-guava.jar \
#       --user-class-path \
#       file:$PWD/com.google.code.findbugs_jsr305-3.0.2.jar \
#       --user-class-path \
#       file:$PWD/org.checkerframework_checker-qual-3.12.0.jar \
#       --user-class-path \
#       file:$PWD/com.google.errorprone_error_prone_annotations-2.11.0.jar \
#       --user-class-path \
#       file:$PWD/com.google.j2objc_j2objc-annotations-1.3.jar \
#       --user-class-path \
#       file:$PWD/com.fasterxml.jackson.core_jackson-core-2.12.6.jar \
#       --user-class-path \
#       file:$PWD/com.fasterxml.jackson.core_jackson-annotations-2.12.6.jar \
#       --user-class-path \
#       file:$PWD/com.fasterxml.jackson.core_jackson-databind-2.12.6.jar \
#       --user-class-path \
#       file:$PWD/com.thoughtworks.paranamer_paranamer-2.8.jar \
#       --user-class-path \
#       file:$PWD/org.yaml_snakeyaml-1.27.jar \
#       --user-class-path \
#       file:$PWD/com.typesafe_config-1.2.1.jar \
#       --user-class-path \
#       file:$PWD/org.apache.commons_commons-pool2-2.0.jar \
#       --user-class-path \
#       file:$PWD/redis.clients_jedis-3.4.1.jar \
#       --user-class-path \
#       file:$PWD/net.snowflake_snowflake-ingest-sdk-0.10.3.jar \
#       --user-class-path \
#       file:$PWD/org.scala-lang_scala-reflect-2.12.10.jar \
#       --user-class-path \
#       file:$PWD/com.fasterxml.jackson.module_jackson-module-paranamer-2.9.8.jar \
#       --user-class-path \
#       file:$PWD/org.slf4j_slf4j-api-1.7.36.jar \
#       1><LOG_DIR>/stdout \
#       2><LOG_DIR>/stderr
#
#   resources:
#     com.microsoft.azure_adal4j-1.6.4.jar -> resource { scheme: "wasbs" host: "h93saq1dkd00l0essko9khde.blob.core.windows.net" port: -1 file: "/user/trusted-service-user/trusted-service-user/.sparkStaging/application_1669964176537_0001/com.microsoft.azure_adal4j-1.6.4.jar" userInfo: "d7f295d5-e18a-4c2b-b25e-b7cc62ab880a" } size: 95776 timestamp: 1669964242000 type: FILE visibility: PRIVATE
#     net.minidev_json-smart-2.3.jar -> resource { scheme: "wasbs" host: "h93saq1dkd00l0essko9khde.blob.core.windows.net" port: -1 file: "/user/trusted-service-user/trusted-service-user/.sparkStaging/application_1669964176537_0001/net.minidev_json-smart-2.3.jar" userInfo: "d7f295d5-e18a-4c2b-b25e-b7cc62ab880a" } size: 120316 timestamp: 1669964246000 type: FILE visibility: PRIVATE
#     com.squareup.retrofit2_retrofit-2.7.2.jar -> resource { scheme: "wasbs" host: "h93saq1dkd00l0essko9khde.blob.core.windows.net" port: -1 file: "/user/trusted-service-user/trusted-service-user/.sparkStaging/application_1669964176537_0001/com.squareup.retrofit2_retrofit-2.7.2.jar" userInfo: "d7f295d5-e18a-4c2b-b25e-b7cc62ab880a" } size: 126050 timestamp: 1669964243000 type: FILE visibility: PRIVATE
#     com.microsoft.azure_azure-annotations-1.10.0.jar -> resource { scheme: "wasbs" host: "h93saq1dkd00l0essko9khde.blob.core.windows.net" port: -1 file: "/user/trusted-service-user/trusted-service-user/.sparkStaging/application_1669964176537_0001/com.microsoft.azure_azure-annotations-1.10.0.jar" userInfo: "d7f295d5-e18a-4c2b-b25e-b7cc62ab880a" } size: 19391 timestamp: 1669964243000 type: FILE visibility: PRIVATE
#     com.squareup.okhttp3_logging-interceptor-3.12.2.jar -> resource { scheme: "wasbs" host: "h93saq1dkd00l0essko9khde.blob.core.windows.net" port: -1 file: "/user/trusted-service-user/trusted-service-user/.sparkStaging/application_1669964176537_0001/com.squareup.okhttp3_logging-interceptor-3.12.2.jar" userInfo: "d7f295d5-e18a-4c2b-b25e-b7cc62ab880a" } size: 12484 timestamp: 1669964244000 type: FILE visibility: PRIVATE
#     com.redislabs_spark-redis_2.12-3.0.0.jar -> resource { scheme: "wasbs" host: "h93saq1dkd00l0essko9khde.blob.core.windows.net" port: -1 file: "/user/trusted-service-user/trusted-service-user/.sparkStaging/application_1669964176537_0001/com.redislabs_spark-redis_2.12-3.0.0.jar" userInfo: "d7f295d5-e18a-4c2b-b25e-b7cc62ab880a" } size: 278382 timestamp: 1669964238000 type: FILE visibility: PRIVATE
#     org.yaml_snakeyaml-1.27.jar -> resource { scheme: "wasbs" host: "h93saq1dkd00l0essko9khde.blob.core.windows.net" port: -1 file: "/user/trusted-service-user/trusted-service-user/.sparkStaging/application_1669964176537_0001/org.yaml_snakeyaml-1.27.jar" userInfo: "d7f295d5-e18a-4c2b-b25e-b7cc62ab880a" } size: 310104 timestamp: 1669964250000 type: FILE visibility: PRIVATE
#     org.checkerframework_checker-qual-3.12.0.jar -> resource { scheme: "wasbs" host: "h93saq1dkd00l0essko9khde.blob.core.windows.net" port: -1 file: "/user/trusted-service-user/trusted-service-user/.sparkStaging/application_1669964176537_0001/org.checkerframework_checker-qual-3.12.0.jar" userInfo: "d7f295d5-e18a-4c2b-b25e-b7cc62ab880a" } size: 208835 timestamp: 1669964248000 type: FILE visibility: PRIVATE
#     io.reactivex_rxjava-1.3.8.jar -> resource { scheme: "wasbs" host: "h93saq1dkd00l0essko9khde.blob.core.windows.net" port: -1 file: "/user/trusted-service-user/trusted-service-user/.sparkStaging/application_1669964176537_0001/io.reactivex_rxjava-1.3.8.jar" userInfo: "d7f295d5-e18a-4c2b-b25e-b7cc62ab880a" } size: 1159165 timestamp: 1669964244000 type: FILE visibility: PRIVATE
#     com.fasterxml.jackson.dataformat_jackson-dataformat-csv-2.12.6.jar -> resource { scheme: "wasbs" host: "h93saq1dkd00l0essko9khde.blob.core.windows.net" port: -1 file: "/user/trusted-service-user/trusted-service-user/.sparkStaging/application_1669964176537_0001/com.fasterxml.jackson.dataformat_jackson-dataformat-csv-2.12.6.jar" userInfo: "d7f295d5-e18a-4c2b-b25e-b7cc62ab880a" } size: 103713 timestamp: 1669964237000 type: FILE visibility: PRIVATE
#     com.squareup.okhttp3_okhttp-urlconnection-3.12.2.jar -> resource { scheme: "wasbs" host: "h93saq1dkd00l0essko9khde.blob.core.windows.net" port: -1 file: "/user/trusted-service-user/trusted-service-user/.sparkStaging/application_1669964176537_0001/com.squareup.okhttp3_okhttp-urlconnection-3.12.2.jar" userInfo: "d7f295d5-e18a-4c2b-b25e-b7cc62ab880a" } size: 34081 timestamp: 1669964244000 type: FILE visibility: PRIVATE
#     com.google.guava_listenablefuture-9999.0-empty-to-avoid-conflict-with-guava.jar -> resource { scheme: "wasbs" host: "h93saq1dkd00l0essko9khde.blob.core.windows.net" port: -1 file: "/user/trusted-service-user/trusted-service-user/.sparkStaging/application_1669964176537_0001/com.google.guava_listenablefuture-9999.0-empty-to-avoid-conflict-with-guava.jar" userInfo: "d7f295d5-e18a-4c2b-b25e-b7cc62ab880a" } size: 2199 timestamp: 1669964248000 type: FILE visibility: PRIVATE
#     com.google.protobuf_protobuf-java-2.6.1.jar -> resource { scheme: "wasbs" host: "h93saq1dkd00l0essko9khde.blob.core.windows.net" port: -1 file: "/user/trusted-service-user/trusted-service-user/.sparkStaging/application_1669964176537_0001/com.google.protobuf_protobuf-java-2.6.1.jar" userInfo: "d7f295d5-e18a-4c2b-b25e-b7cc62ab880a" } size: 596642 timestamp: 1669964238000 type: FILE visibility: PRIVATE
#     com.fasterxml.jackson.core_jackson-annotations-2.12.6.jar -> resource { scheme: "wasbs" host: "h93saq1dkd00l0essko9khde.blob.core.windows.net" port: -1 file: "/user/trusted-service-user/trusted-service-user/.sparkStaging/application_1669964176537_0001/com.fasterxml.jackson.core_jackson-annotations-2.12.6.jar" userInfo: "d7f295d5-e18a-4c2b-b25e-b7cc62ab880a" } size: 75708 timestamp: 1669964249000 type: FILE visibility: PRIVATE
#     com.squareup.okhttp3_okhttp-3.12.6.jar -> resource { scheme: "wasbs" host: "h93saq1dkd00l0essko9khde.blob.core.windows.net" port: -1 file: "/user/trusted-service-user/trusted-service-user/.sparkStaging/application_1669964176537_0001/com.squareup.okhttp3_okhttp-3.12.6.jar" userInfo: "d7f295d5-e18a-4c2b-b25e-b7cc62ab880a" } size: 423175 timestamp: 1669964243000 type: FILE visibility: PRIVATE
#     org.apache.commons_commons-lang3-3.12.0.jar -> resource { scheme: "wasbs" host: "h93saq1dkd00l0essko9khde.blob.core.windows.net" port: -1 file: "/user/trusted-service-user/trusted-service-user/.sparkStaging/application_1669964176537_0001/org.apache.commons_commons-lang3-3.12.0.jar" userInfo: "d7f295d5-e18a-4c2b-b25e-b7cc62ab880a" } size: 587402 timestamp: 1669964239000 type: FILE visibility: PRIVATE
#     org.scala-lang_scala-reflect-2.12.10.jar -> resource { scheme: "wasbs" host: "h93saq1dkd00l0essko9khde.blob.core.windows.net" port: -1 file: "/user/trusted-service-user/trusted-service-user/.sparkStaging/application_1669964176537_0001/org.scala-lang_scala-reflect-2.12.10.jar" userInfo: "d7f295d5-e18a-4c2b-b25e-b7cc62ab880a" } size: 3678534 timestamp: 1669964251000 type: FILE visibility: PRIVATE
#     org.xerial.snappy_snappy-java-1.1.8.4.jar -> resource { scheme: "wasbs" host: "h93saq1dkd00l0essko9khde.blob.core.windows.net" port: -1 file: "/user/trusted-service-user/trusted-service-user/.sparkStaging/application_1669964176537_0001/org.xerial.snappy_snappy-java-1.1.8.4.jar" userInfo: "d7f295d5-e18a-4c2b-b25e-b7cc62ab880a" } size: 1970939 timestamp: 1669964248000 type: FILE visibility: PRIVATE
#     net.snowflake_snowflake-jdbc-3.13.18.jar -> resource { scheme: "wasbs" host: "h93saq1dkd00l0essko9khde.blob.core.windows.net" port: -1 file: "/user/trusted-service-user/trusted-service-user/.sparkStaging/application_1669964176537_0001/net.snowflake_snowflake-jdbc-3.13.18.jar" userInfo: "d7f295d5-e18a-4c2b-b25e-b7cc62ab880a" } size: 28860489 timestamp: 1669964239000 type: FILE visibility: PRIVATE
#     org.eclipse.jetty_jetty-util-9.3.24.v20180605.jar -> resource { scheme: "wasbs" host: "h93saq1dkd00l0essko9khde.blob.core.windows.net" port: -1 file: "/user/trusted-service-user/trusted-service-user/.sparkStaging/application_1669964176537_0001/org.eclipse.jetty_jetty-util-9.3.24.v20180605.jar" userInfo: "d7f295d5-e18a-4c2b-b25e-b7cc62ab880a" } size: 458642 timestamp: 1669964240000 type: FILE visibility: PRIVATE
#     org.apache.commons_commons-pool2-2.0.jar -> resource { scheme: "wasbs" host: "h93saq1dkd00l0essko9khde.blob.core.windows.net" port: -1 file: "/user/trusted-service-user/trusted-service-user/.sparkStaging/application_1669964176537_0001/org.apache.commons_commons-pool2-2.0.jar" userInfo: "d7f295d5-e18a-4c2b-b25e-b7cc62ab880a" } size: 107063 timestamp: 1669964250000 type: FILE visibility: PRIVATE
#     com.microsoft.sqlserver_mssql-jdbc-10.2.0.jre8.jar -> resource { scheme: "wasbs" host: "h93saq1dkd00l0essko9khde.blob.core.windows.net" port: -1 file: "/user/trusted-service-user/trusted-service-user/.sparkStaging/application_1669964176537_0001/com.microsoft.sqlserver_mssql-jdbc-10.2.0.jre8.jar" userInfo: "d7f295d5-e18a-4c2b-b25e-b7cc62ab880a" } size: 1393722 timestamp: 1669964240000 type: FILE visibility: PRIVATE
# ...
# 22/12/02 06:59:40 INFO metrics: type=TIMER, name=application_1669964176537_0001.driver.LiveListenerBus.queue.eventLog.listenerProcessingTime, count=9, min=22.35902, max=103.917729, mean=43.463543808087906, stddev=25.218883896298628, p50=31.224688, p75=45.709336, p95=103.917729, p98=103.917729, p99=103.917729, p999=103.917729, m1_rate=0.952026648777594, m5_rate=0.9900828722929707, m15_rate=0.996675908802938, mean_rate=0.8844708845777149, rate_unit=events/second, duration_unit=milliseconds
# 22/12/02 06:59:40 INFO metrics: type=TIMER, name=application_1669964176537_0001.driver.LiveListenerBus.queue.executorManagement.listenerProcessingTime, count=9, min=0.0293, max=12.449755, mean=1.4781316459947282, stddev=3.78854253660637, p50=0.06, p75=0.0877, p95=12.449755, p98=12.449755, p99=12.449755, p999=12.449755, m1_rate=0.952026648777594, m5_rate=0.9900828722929707, m15_rate=0.996675908802938, mean_rate=0.8265443621308588, rate_unit=events/second, duration_unit=milliseconds
# 22/12/02 06:59:40 INFO metrics: type=TIMER, name=application_1669964176537_0001.driver.LiveListenerBus.queue.shared.listenerProcessingTime, count=9, min=0.928497, max=452.693379, mean=124.29649280863661, stddev=153.18136286106454, p50=43.068446, p75=229.170579, p95=452.693379, p98=452.693379, p99=452.693379, p999=452.693379, m1_rate=0.952026648777594, m5_rate=0.9900828722929707, m15_rate=0.996675908802938, mean_rate=0.8219015857583628, rate_unit=events/second, duration_unit=milliseconds
# 22/12/02 06:59:40 INFO YarnAllocator: Driver requested a total number of 0 executor(s), reset all resource profile ids
# 22/12/02 06:59:40 INFO YarnClusterSchedulerBackend: Shutting down all executors
# 22/12/02 06:59:40 INFO YarnSchedulerBackend$YarnDriverEndpoint: Asking each executor to shut down
# 22/12/02 06:59:40 INFO MapOutputTrackerMasterEndpoint: MapOutputTrackerMasterEndpoint stopped!
# 22/12/02 06:59:40 INFO MemoryStore: MemoryStore cleared
# 22/12/02 06:59:40 INFO BlockManager: BlockManager stopped
# 22/12/02 06:59:40 INFO BlockManagerMaster: BlockManagerMaster stopped
# 22/12/02 06:59:40 INFO OutputCommitCoordinator$OutputCommitCoordinatorEndpoint: OutputCommitCoordinator stopped!
# 22/12/02 06:59:40 INFO SparkContext: Successfully stopped SparkContext
# 22/12/02 06:59:40 INFO ApplicationMaster: Unregistering ApplicationMaster with FAILED (diag message: User application exited with status 1, error msg: ed-service-user/appcache/application_1669964176537_0001/container_1669964176537_0001_02_000001/com.fasterxml.jackson.datatype_jackson-datatype-joda-2.10.1.jar
#   /mnt/var/hadoop/tmp/nm-local-dir/usercache/trusted-service-user/appcache/application_1669964176537_0001/container_1669964176537_0001_02_000001/io.reactivex_rxjava-1.3.8.jar
#   /mnt/var/hadoop/tmp/nm-local-dir/usercache/trusted-service-user/appcache/application_1669964176537_0001/container_1669964176537_0001_02_000001/com.squareup.retrofit2_adapter-rxjava-2.7.2.jar
#   /mnt/var/hadoop/tmp/nm-local-dir/usercache/trusted-service-user/appcache/application_1669964176537_0001/container_1669964176537_0001_02_000001/com.squareup.okio_okio-1.15.0.jar
#   /mnt/var/hadoop/tmp/nm-local-dir/usercache/trusted-service-user/appcache/application_1669964176537_0001/container_1669964176537_0001_02_000001/joda-time_joda-time-2.9.9.jar
#   /mnt/var/hadoop/tmp/nm-local-dir/usercache/trusted-service-user/appcache/application_1669964176537_0001/container_1669964176537_0001_02_000001/com.nimbusds_oauth2-oidc-sdk-6.5.jar
#   /mnt/var/hadoop/tmp/nm-local-dir/usercache/trusted-service-user/appcache/application_1669964176537_0001/container_1669964176537_0001_02_000001/com.google.code.gson_gson-2.8.0.jar
#   /mnt/var/hadoop/tmp/nm-local-dir/usercache/trusted-service-user/appcache/application_1669964176537_0001/container_1669964176537_0001_02_000001/com.sun.mail_javax.mail-1.6.1.jar
#   /mnt/var/hadoop/tmp/nm-local-dir/usercache/trusted-service-user/appcache/application_1669964176537_0001/container_1669964176537_0001_02_000001/com.github.stephenc.jcip_jcip-annotations-1.0-1.jar
#   /mnt/var/hadoop/tmp/nm-local-dir/usercache/trusted-service-user/appcache/application_1669964176537_0001/container_1669964176537_0001_02_000001/net.minidev_json-smart-2.3.jar
#   /mnt/var/hadoop/tmp/nm-local-dir/usercache/trusted-service-user/appcache/application_1669964176537_0001/container_1669964176537_0001_02_000001/com.nimbusds_lang-tag-1.7.jar
#   /mnt/var/hadoop/tmp/nm-local-dir/usercache/trusted-service-user/appcache/application_1669964176537_0001/container_1669964176537_0001_02_000001/javax.activation_activation-1.1.jar
#   /mnt/var/hadoop/tmp/nm-local-dir/usercache/trusted-service-user/appcache/application_1669964176537_0001/container_1669964176537_0001_02_000001/net.minidev_accessors-smart-1.2.jar
#   /mnt/var/hadoop/tmp/nm-local-dir/usercache/trusted-service-user/appcache/application_1669964176537_0001/container_1669964176537_0001_02_000001/org.ow2.asm_asm-5.0.4.jar
#   /mnt/var/hadoop/tmp/nm-local-dir/usercache/trusted-service-user/appcache/application_1669964176537_0001/container_1669964176537_0001_02_000001/com.github.luben_zstd-jni-1.5.0-4.jar
#   /mnt/var/hadoop/tmp/nm-local-dir/usercache/trusted-service-user/appcache/application_1669964176537_0001/container_1669964176537_0001_02_000001/org.lz4_lz4-java-1.8.0.jar
#   /mnt/var/hadoop/tmp/nm-local-dir/usercache/trusted-service-user/appcache/application_1669964176537_0001/container_1669964176537_0001_02_000001/org.xerial.snappy_snappy-java-1.1.8.4.jar
#   /mnt/var/hadoop/tmp/nm-local-dir/usercache/trusted-service-user/appcache/application_1669964176537_0001/container_1669964176537_0001_02_000001/com.google.guava_failureaccess-1.0.1.jar
#   /mnt/var/hadoop/tmp/nm-local-dir/usercache/trusted-service-user/appcache/application_1669964176537_0001/container_1669964176537_0001_02_000001/com.google.guava_listenablefuture-9999.0-empty-to-avoid-conflict-with-guava.jar
#   /mnt/var/hadoop/tmp/nm-local-dir/usercache/trusted-service-user/appcache/application_1669964176537_0001/container_1669964176537_0001_02_000001/com.google.code.findbugs_jsr305-3.0.2.jar
#   /mnt/var/hadoop/tmp/nm-local-dir/usercache/trusted-service-user/appcache/application_1669964176537_0001/container_1669964176537_0001_02_000001/org.checkerframework_checker-qual-3.12.0.jar
#   /mnt/var/hadoop/tmp/nm-local-dir/usercache/trusted-service-user/appcache/application_1669964176537_0001/container_1669964176537_0001_02_000001/com.google.errorprone_error_prone_annotations-2.11.0.jar
#   /mnt/var/hadoop/tmp/nm-local-dir/usercache/trusted-service-user/appcache/application_1669964176537_0001/container_1669964176537_0001_02_000001/com.google.j2objc_j2objc-annotations-1.3.jar
#   /mnt/var/hadoop/tmp/nm-local-dir/usercache/trusted-service-user/appcache/application_1669964176537_0001/container_1669964176537_0001_02_000001/com.fasterxml.jackson.core_jackson-core-2.12.6.jar
#   /mnt/var/hadoop/tmp/nm-local-dir/usercache/trusted-service-user/appcache/application_1669964176537_0001/container_1669964176537_0001_02_000001/com.fasterxml.jackson.core_jackson-annotations-2.12.6.jar
#   /mnt/var/hadoop/tmp/nm-local-dir/usercache/trusted-service-user/appcache/application_1669964176537_0001/container_1669964176537_0001_02_000001/com.fasterxml.jackson.core_jackson-databind-2.12.6.jar
#   /mnt/var/hadoop/tmp/nm-local-dir/usercache/trusted-service-user/appcache/application_1669964176537_0001/container_1669964176537_0001_02_000001/com.thoughtworks.paranamer_paranamer-2.8.jar
#   /mnt/var/hadoop/tmp/nm-local-dir/usercache/trusted-service-user/appcache/application_1669964176537_0001/container_1669964176537_0001_02_000001/org.yaml_snakeyaml-1.27.jar
#   /mnt/var/hadoop/tmp/nm-local-dir/usercache/trusted-service-user/appcache/application_1669964176537_0001/container_1669964176537_0001_02_000001/com.typesafe_config-1.2.1.jar
#   /mnt/var/hadoop/tmp/nm-local-dir/usercache/trusted-service-user/appcache/application_1669964176537_0001/container_1669964176537_0001_02_000001/org.apache.commons_commons-pool2-2.0.jar
#   /mnt/var/hadoop/tmp/nm-local-dir/usercache/trusted-service-user/appcache/application_1669964176537_0001/container_1669964176537_0001_02_000001/redis.clients_jedis-3.4.1.jar
#   /mnt/var/hadoop/tmp/nm-local-dir/usercache/trusted-service-user/appcache/application_1669964176537_0001/container_1669964176537_0001_02_000001/net.snowflake_snowflake-ingest-sdk-0.10.3.jar
#   /mnt/var/hadoop/tmp/nm-local-dir/usercache/trusted-service-user/appcache/application_1669964176537_0001/container_1669964176537_0001_02_000001/org.scala-lang_scala-reflect-2.12.10.jar
#   /mnt/var/hadoop/tmp/nm-local-dir/usercache/trusted-service-user/appcache/application_1669964176537_0001/container_1669964176537_0001_02_000001/com.fasterxml.jackson.module_jackson-module-paranamer-2.9.8.jar
#   /mnt/var/hadoop/tmp/nm-local-dir/usercache/trusted-service-user/appcache/application_1669964176537_0001/container_1669964176537_0001_02_000001/org.slf4j_slf4j-api-1.7.36.jar
#   /home/trusted-service-user/cluster-env/env/lib/python38.zip
#   /home/trusted-service-user/cluster-env/env/lib/python3.8
#   /home/trusted-service-user/cluster-env/env/lib/python3.8/lib-dynload
#   /home/trusted-service-user/cluster-env/env/lib/python3.8/site-packages
#   /usr/hdp/current/spark3-client/jars/delta-core_2.12-1.0.0.8.jar
#   /usr/hdp/current/spark3-client/jars/hyperspace-core-spark3.1_2.12-0.5.0-synapse.jar
#   /usr/hdp/current/spark3-client/jars/impulse-core_spark3.1_2.12-1.0.3.jar
#   /usr/hdp/current/spark3-client/jars/impulse-telemetry-mds_spark3.1_2.12-1.0.3.jar
#   /home/trusted-service-user/cluster-env/env/lib/python3.8/site-packages/locket-0.2.1-py3.8.egg
#   warnings.warn(
# pyspark_client.py: Preprocessing via UDFs and submit Spark job.
# FeatureGenConfig is provided. Executing FeatureGenJob.
# submit_spark_job: feature_names_funcs:
# {'f_location_avg_fare,f_location_max_fare,f_location_total_fare_cents': <function feathr_udf_day_calc at 0x7f6c641dec10>}
# set(feature_names_funcs.keys()):
# {'f_location_avg_fare,f_location_max_fare,f_location_total_fare_cents'}
# submit_spark_job: Load DataFrame from Scala engine.
# Traceback (most recent call last):
#   File "feathr_pyspark_driver.py", line 106, in <module>
#     submit_spark_job(feature_names_funcs)
#   File "feathr_pyspark_driver.py", line 64, in submit_spark_job
#     dataframeFromSpark = py4j_feature_job.loadSourceDataframe(job_param_java_array, set(feature_names_funcs.keys())) # TODO: Add data handler support here
#   File "/home/trusted-service-user/cluster-env/env/lib/python3.8/site-packages/py4j/java_gateway.py", line 1304, in __call__
#     return_value = get_return_value(
#   File "/opt/spark/python/lib/pyspark.zip/pyspark/sql/utils.py", line 111, in deco
#   File "/home/trusted-service-user/cluster-env/env/lib/python3.8/site-packages/py4j/protocol.py", line 326, in get_return_value
#     raise Py4JJavaError(
# py4j.protocol.Py4JJavaError: An error occurred while calling z:com.linkedin.feathr.offline.job.FeatureGenJob.loadSourceDataframe.
# : java.lang.NullPointerException
# 	at java.util.Hashtable.put(Hashtable.java:460)
# 	at java.util.Properties.setProperty(Properties.java:166)
# 	at java.lang.System.setProperty(System.java:798)
# 	at scala.util.PropertiesTrait.setProp(Properties.scala:60)
# 	at scala.util.PropertiesTrait.setProp$(Properties.scala:60)
# 	at scala.util.Properties$.setProp(Properties.scala:20)
# 	at com.linkedin.feathr.offline.job.FeatureGenJob$.$anonfun$parseInputArguments$2(FeatureGenJob.scala:64)
# 	at scala.collection.mutable.HashMap.$anonfun$foreach$1(HashMap.scala:149)
# 	at scala.collection.mutable.HashTable.foreachEntry(HashTable.scala:237)
# 	at scala.collection.mutable.HashTable.foreachEntry$(HashTable.scala:230)
# 	at scala.collection.mutable.HashMap.foreachEntry(HashMap.scala:44)
# 	at scala.collection.mutable.HashMap.foreach(HashMap.scala:149)
# 	at com.linkedin.feathr.offline.job.FeatureGenJob$.parseInputArguments(FeatureGenJob.scala:64)
# 	at com.linkedin.feathr.offline.job.FeatureGenJob$.prepareSparkSession(FeatureGenJob.scala:248)
# 	at com.linkedin.feathr.offline.job.FeatureGenJob$.loadSourceDataframe(FeatureGenJob.scala:210)
# 	at com.linkedin.feathr.offline.job.FeatureGenJob.loadSourceDataframe(FeatureGenJob.scala)
# 	at sun.reflect.NativeMethodAccessorImpl.invoke0(Native Method)
# 	at sun.reflect.NativeMethodAccessorImpl.invoke(NativeMethodAccessorImpl.java:62)
# 	at sun.reflect.DelegatingMethodAccessorImpl.invoke(DelegatingMethodAccessorImpl.java:43)
# 	at java.lang.reflect.Method.invoke(Method.java:498)
# 	at py4j.reflection.MethodInvoker.invoke(MethodInvoker.java:244)
# 	at py4j.reflection.ReflectionEngine.invoke(ReflectionEngine.java:357)
# 	at py4j.Gateway.invoke(Gateway.java:282)
# 	at py4j.commands.AbstractCommand.invokeMethod(AbstractCommand.java:132)
# 	at py4j.commands.CallCommand.execute(CallCommand.java:79)
# 	at py4j.GatewayConnection.run(GatewayConnection.java:238)
# 	at java.lang.Thread.run(Thread.java:750)
#
# )
# 22/12/02 06:59:40 INFO AMRMClientImpl: Waiting for application to be successfully unregistered.
# 22/12/02 06:59:40 INFO ApplicationMaster: Deleting staging directory wasbs://d7f295d5-e18a-4c2b-b25e-b7cc62ab880a@h93saq1dkd00l0essko9khde.blob.core.windows.net/user/trusted-service-user/trusted-service-user/.sparkStaging/application_1669964176537_0001
# 22/12/02 06:59:40 WARN AzureFileSystemThreadPoolExecutor: Disabling threads for Delete operation as thread count 0 is <= 1
# 22/12/02 06:59:41 INFO AzureFileSystemThreadPoolExecutor: Time taken for Delete operation is: 643 ms with threads: 0
# 22/12/02 06:59:41 INFO RpcAppSparkContextServer: Closing remote SparkContext service at 10.0.32.4:18083, remoteSparkContext/remoteSparkContextEndpoint
# 22/12/02 06:59:41 INFO RpcAppEventQueue: Max number of events in queue: 6.
# 22/12/02 06:59:41 INFO RpcAppSender: Closing RPC app sender
# 22/12/02 06:59:41 INFO RpcAppSender: Sending remaining events
# 22/12/02 06:59:41 INFO RpcAppSender: Sent RPC app end event of application_1669964176537_0001/2
# 22/12/02 06:59:41 INFO RpcAppSender: RPC app sender closed
# 22/12/02 06:59:41 INFO ShutdownHookManager: Shutdown hook called
# 22/12/02 06:59:41 INFO ShutdownHookManager: Deleting directory /mnt/var/hadoop/tmp/nm-local-dir/usercache/trusted-service-user/appcache/application_1669964176537_0001/spark-198eec65-fbb5-4ee1-8da0-0e0a2b2b65b6
# 22/12/02 06:59:41 INFO ShutdownHookManager: Deleting directory /mnt/var/hadoop/tmp/nm-local-dir/usercache/trusted-service-user/appcache/application_1669964176537_0001/spark-198eec65-fbb5-4ee1-8da0-0e0a2b2b65b6/pyspark-66962c53-f423-483c-b677-f44c961565b1
#
# 2022-12-02 08:00:06.092 | ERROR    | feathr.spark_provider._synapse_submission:wait_for_completion:184 - The size of the whole error log is: 243546. The logs might be truncated in some cases (such as in Visual Studio Code) so only the top a few lines of the error message is displayed. If you cannot see the whole log, you may want to extend the setting for output size limit.
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In [14], line 19
#      13 settings = MaterializationSettings(name="nycTaxiFeatures",
#      14                                    backfill_time=backfill_time,
#      15                                    sinks=[SQLSink],
#      16                                    feature_names=["f_location_avg_fare", "f_location_max_fare"])
#      18 feathr_client.materialize_features(settings)
# ---> 19 feathr_client.wait_job_to_finish(timeout_sec=500)
#
# File c:\Users\risengupta\Miniconda3\envs\datascience-env\lib\site-packages\feathr\client.py:736, in FeathrClient.wait_job_to_finish(self, timeout_sec)
#     734     return
#     735 else:
# --> 736     raise RuntimeError('Spark job failed.')
#
# RuntimeError: Spark job failed.

# %% [markdown]
# We can then get the features from the online store (Redis in our case):

# %%
res = feathr_client.multi_get_online_features("nyctaxifs", ["128", "243"], ["f_location_avg_fare", "f_location_max_fare"])
res
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# File c:\Users\risengupta\Miniconda3\envs\datascience-env\lib\site-packages\redis\connection.py:1380, in ConnectionPool.get_connection(self, command_name, *keys, **options)
#    1379 try:
# -> 1380     connection = self._available_connections.pop()
#    1381 except IndexError:
#
# IndexError: pop from empty list
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Cell In [15], line 1
# ----> 1 res = feathr_client.multi_get_online_features("nyctaxifs", ["128", "243"], ["f_location_avg_fare", "f_location_max_fare"])
#       2 res
#
# File c:\Users\risengupta\Miniconda3\envs\datascience-env\lib\site-packages\feathr\client.py:299, in FeathrClient.multi_get_online_features(self, feature_table, keys, feature_names)
#     297         redis_key = self._construct_redis_key(feature_table, key)
#     298         redis_pipeline.hmget(redis_key, *feature_names)
# --> 299     pipeline_result = redis_pipeline.execute()
#     301 decoded_pipeline_result = []
#     302 for feature_list in pipeline_result:
#
# File c:\Users\risengupta\Miniconda3\envs\datascience-env\lib\site-packages\redis\client.py:2072, in Pipeline.execute(self, raise_on_error)
#    2070 conn = self.connection
#    2071 if not conn:
# -> 2072     conn = self.connection_pool.get_connection("MULTI", self.shard_hint)
#    2073     # assign to self.connection so reset() releases the connection
#    2074     # back to the pool after we're done
#    2075     self.connection = conn
#
# File c:\Users\risengupta\Miniconda3\envs\datascience-env\lib\site-packages\redis\connection.py:1382, in ConnectionPool.get_connection(self, command_name, *keys, **options)
#    1380         connection = self._available_connections.pop()
#    1381     except IndexError:
# -> 1382         connection = self.make_connection()
#    1383     self._in_use_connections.add(connection)
#    1385 try:
#    1386     # ensure this connection is connected to Redis
#
# File c:\Users\risengupta\Miniconda3\envs\datascience-env\lib\site-packages\redis\connection.py:1422, in ConnectionPool.make_connection(self)
#    1420     raise ConnectionError("Too many connections")
#    1421 self._created_connections += 1
# -> 1422 return self.connection_class(**self.connection_kwargs)
#
# File c:\Users\risengupta\Miniconda3\envs\datascience-env\lib\site-packages\redis\connection.py:539, in Connection.__init__(self, host, port, db, password, socket_timeout, socket_connect_timeout, socket_keepalive, socket_keepalive_options, socket_type, retry_on_timeout, retry_on_error, encoding, encoding_errors, decode_responses, parser_class, socket_read_size, health_check_interval, client_name, username, retry, redis_connect_func)
#     537 self.pid = os.getpid()
#     538 self.host = host
# --> 539 self.port = int(port)
#     540 self.db = db
#     541 self.username = username
#
# TypeError: int() argument must be a string, a bytes-like object or a real number, not 'NoneType'

# %%
feathr_client.get_online_features("dbo.nyctaxifs", "128", ["f_location_avg_fare", "f_location_max_fare"])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# File c:\Users\risengupta\Miniconda3\envs\datascience-env\lib\site-packages\redis\connection.py:1380, in ConnectionPool.get_connection(self, command_name, *keys, **options)
#    1379 try:
# -> 1380     connection = self._available_connections.pop()
#    1381 except IndexError:
#
# IndexError: pop from empty list
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Cell In [13], line 1
# ----> 1 feathr_client.get_online_features("dbo.nyctaxifs", "128", ["f_location_avg_fare", "f_location_max_fare"])
#
# File c:\Users\risengupta\Miniconda3\envs\datascience-env\lib\site-packages\feathr\client.py:275, in FeathrClient.get_online_features(self, feature_table, key, feature_names)
#     258 """Fetches feature value for a certain key from a online feature table.
#     259
#     260 Args:
#    (...)
#     272     [None, b'4.0', b'31.0', b'23.0'].
#     273     """
#     274 redis_key = self._construct_redis_key(feature_table, key)
# --> 275 res = self.redis_client.hmget(redis_key, *feature_names)
#     276 return self._decode_proto(res)
#
# File c:\Users\risengupta\Miniconda3\envs\datascience-env\lib\site-packages\redis\commands\core.py:4879, in HashCommands.hmget(self, name, keys, *args)
#    4873 """
#    4874 Returns a list of values ordered identically to ``keys``
#    4875
#    4876 For more information see https://redis.io/commands/hmget
#    4877 """
#    4878 args = list_or_args(keys, args)
# -> 4879 return self.execute_command("HMGET", name, *args)
#
# File c:\Users\risengupta\Miniconda3\envs\datascience-env\lib\site-packages\redis\client.py:1235, in Redis.execute_command(self, *args, **options)
#    1233 pool = self.connection_pool
#    1234 command_name = args[0]
# -> 1235 conn = self.connection or pool.get_connection(command_name, **options)
#    1237 try:
#    1238     return conn.retry.call_with_retry(
#    1239         lambda: self._send_command_parse_response(
#    1240             conn, command_name, *args, **options
#    1241         ),
#    1242         lambda error: self._disconnect_raise(conn, error),
#    1243     )
#
# File c:\Users\risengupta\Miniconda3\envs\datascience-env\lib\site-packages\redis\connection.py:1382, in ConnectionPool.get_connection(self, command_name, *keys, **options)
#    1380         connection = self._available_connections.pop()
#    1381     except IndexError:
# -> 1382         connection = self.make_connection()
#    1383     self._in_use_connections.add(connection)
#    1385 try:
#    1386     # ensure this connection is connected to Redis
#
# File c:\Users\risengupta\Miniconda3\envs\datascience-env\lib\site-packages\redis\connection.py:1422, in ConnectionPool.make_connection(self)
#    1420     raise ConnectionError("Too many connections")
#    1421 self._created_connections += 1
# -> 1422 return self.connection_class(**self.connection_kwargs)
#
# File c:\Users\risengupta\Miniconda3\envs\datascience-env\lib\site-packages\redis\connection.py:539, in Connection.__init__(self, host, port, db, password, socket_timeout, socket_connect_timeout, socket_keepalive, socket_keepalive_options, socket_type, retry_on_timeout, retry_on_error, encoding, encoding_errors, decode_responses, parser_class, socket_read_size, health_check_interval, client_name, username, retry, redis_connect_func)
#     537 self.pid = os.getpid()
#     538 self.host = host
# --> 539 self.port = int(port)
#     540 self.db = db
#     541 self.username = username
#
# TypeError: int() argument must be a string, a bytes-like object or a real number, not 'NoneType'

# %%
import os

print(os.environ)
# Out:
# environ({'ALLUSERSPROFILE': 'C:\\ProgramData', 'APPDATA': 'C:\\Users\\risengupta\\AppData\\Roaming', 'APPLICATION_INSIGHTS_NO_DIAGNOSTIC_CHANNEL': 'true', 'CHOCOLATEYINSTALL': 'C:\\ProgramData\\chocolatey', 'CHOCOLATEYLASTPATHUPDATE': '133131757029497056', 'CHOCOLATEYTOOLSLOCATION': 'C:\\tools', 'COMMONPROGRAMFILES': 'C:\\Program Files\\Common Files', 'COMMONPROGRAMFILES(X86)': 'C:\\Program Files (x86)\\Common Files', 'COMMONPROGRAMW6432': 'C:\\Program Files\\Common Files', 'COMPUTERNAME': 'RJSURFACEBOOK', 'COMSPEC': 'C:\\WINDOWS\\system32\\cmd.exe', 'CONDA_DEFAULT_ENV': 'datascience-env', 'CONDA_EXE': 'C:\\Users\\risengupta\\Miniconda3\\Scripts\\conda.exe', 'CONDA_PREFIX': 'C:\\Users\\risengupta\\Miniconda3\\envs\\datascience-env', 'CONDA_PREFIX_1': 'C:\\Users\\risengupta\\Miniconda3', 'CONDA_PROMPT_MODIFIER': '(datascience-env) ', 'CONDA_PYTHON_EXE': 'C:\\Users\\risengupta\\Miniconda3\\python.exe', 'CONDA_SHLVL': '2', 'DRIVERDATA': 'C:\\Windows\\System32\\Drivers\\DriverData', 'ELECTRON_RUN_AS_NODE': '1', 'FPS_BROWSER_APP_PROFILE_STRING': 'Internet Explorer', 'FPS_BROWSER_USER_PROFILE_STRING': 'Default', 'HOMEDRIVE': 'C:', 'HOMEPATH': '\\Users\\risengupta', 'JPY_INTERRUPT_EVENT': '3076', 'LOCALAPPDATA': 'C:\\Users\\risengupta\\AppData\\Local', 'LOGONSERVER': '\\\\RJSURFACEBOOK', 'NUMBER_OF_PROCESSORS': '8', 'ONEDRIVE': 'C:\\Users\\risengupta\\OneDrive - Microsoft', 'ONEDRIVECOMMERCIAL': 'C:\\Users\\risengupta\\OneDrive - Microsoft', 'ORIGINAL_XDG_CURRENT_DESKTOP': 'undefined', 'OS': 'Windows_NT', 'PATH': 'c:\\Users\\risengupta\\Miniconda3\\envs\\datascience-env;C:\\Users\\risengupta\\Miniconda3\\envs\\datascience-env;C:\\Users\\risengupta\\Miniconda3\\envs\\datascience-env\\Library\\mingw-w64\\bin;C:\\Users\\risengupta\\Miniconda3\\envs\\datascience-env\\Library\\usr\\bin;C:\\Users\\risengupta\\Miniconda3\\envs\\datascience-env\\Library\\bin;C:\\Users\\risengupta\\Miniconda3\\envs\\datascience-env\\Scripts;C:\\Users\\risengupta\\Miniconda3\\envs\\datascience-env\\bin;C:\\Users\\risengupta\\Miniconda3\\condabin;C:\\Python310\\Scripts;C:\\Python310;C:\\Program Files (x86)\\Microsoft SDKs\\Azure\\CLI2\\wbin;C:\\WINDOWS\\system32;C:\\WINDOWS;C:\\WINDOWS\\System32\\Wbem;C:\\WINDOWS\\System32\\WindowsPowerShell\\v1.0;C:\\WINDOWS\\System32\\OpenSSH;C:\\Program Files\\Git\\cmd;C:\\Program Files\\dotnet;C:\\Program Files\\nodejs;C:\\ProgramData\\chocolatey\\bin;.;C:\\Program Files (x86)\\oh-my-posh\\bin;C:\\Program Files\\Docker\\Docker\\resources\\bin;C:\\Users\\risengupta\\.pyenv\\pyenv-win\\bin;C:\\Users\\risengupta\\.pyenv\\pyenv-win\\shims;C:\\Users\\risengupta\\Miniconda3;C:\\Users\\risengupta\\Miniconda3\\Library\\mingw-w64\\bin;C:\\Users\\risengupta\\Miniconda3\\Library\\usr\\bin;C:\\Users\\risengupta\\Miniconda3\\Library\\bin;C:\\Users\\risengupta\\Miniconda3\\Scripts;C:\\Users\\risengupta\\scoop\\apps\\oh-my-posh\\current\\bin;C:\\Users\\risengupta\\scoop\\shims;C:\\Users\\risengupta\\.poetry\\bin;C:\\Users\\risengupta\\AppData\\Local\\Microsoft\\WindowsApps;C:\\Users\\risengupta\\AppData\\Local\\Programs\\Microsoft VS Code\\bin;C:\\Users\\risengupta\\AppData\\Roaming\\npm;C:\\Users\\risengupta\\AppData\\Local\\Programs\\oh-my-posh\\bin;C:\\Users\\risengupta\\AppData\\Local\\Microsoft\\WindowsApps;C:\\Users\\risengupta\\.dotnet\\tools;C:\\Users\\risengupta\\AppData\\Local\\Programs\\Azure Data Studio\\bin', 'PATHEXT': '.COM;.EXE;.BAT;.CMD;.VBS;.VBE;.JS;.JSE;.WSF;.WSH;.MSC;.PY;.PYW', 'POSH_THEMES_PATH': 'C:\\Users\\risengupta\\AppData\\Local\\Programs\\oh-my-posh\\themes', 'PROCESSOR_ARCHITECTURE': 'AMD64', 'PROCESSOR_IDENTIFIER': 'Intel64 Family 6 Model 126 Stepping 5, GenuineIntel', 'PROCESSOR_LEVEL': '6', 'PROCESSOR_REVISION': '7e05', 'PROGRAMDATA': 'C:\\ProgramData', 'PROGRAMFILES': 'C:\\Program Files', 'PROGRAMFILES(X86)': 'C:\\Program Files (x86)', 'PROGRAMW6432': 'C:\\Program Files', 'PROMPT': '(datascience-env) $P$G', 'PSMODULEPATH': 'C:\\Program Files\\WindowsPowerShell\\Modules;C:\\WINDOWS\\system32\\WindowsPowerSh ...
